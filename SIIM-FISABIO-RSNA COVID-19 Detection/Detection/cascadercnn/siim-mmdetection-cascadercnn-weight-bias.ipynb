# %% [markdown]
# ![](https://i.ibb.co/LP8YffP/lung-nb2-short.jpg)
#
# <p style='text-align: right;'><span style="color: #000508; font-family: Segoe UI; font-size: 0.7em; font-weight: 300;">Image Source: https://www.hopkinsmedicine.org/health/</span></p>
#
# <p style='text-align: center;'><span style="color: #000508; font-family: Segoe UI; font-size: 2.5em; font-weight: 300;">SIIM COVID-19 MMDetection+CascadeRCNN+Weight&Bias</span></p>

# %% [markdown]
# <span style="color: #E45D00; font-family: Segoe UI; font-size: 1.9em; font-weight: 300;">Overview</span>
#
# &nbsp;&nbsp;✅&nbsp;&nbsp;MMDetection and Weights & Biases Setup<br>
# &nbsp;&nbsp;✅&nbsp;&nbsp;Preparation of MMDetection Config<br>
# &nbsp;&nbsp;✅&nbsp;&nbsp;Weights & Biases Integration<br>
# &nbsp;&nbsp;✅&nbsp;&nbsp;Training and Evaluation<br>
# &nbsp;&nbsp;✅&nbsp;&nbsp;Experiment Tracking and Logging with Weights & Biases<br>
# &nbsp;&nbsp;✅&nbsp;&nbsp;Storing Model Files as Artifacts<br>
# &nbsp;&nbsp;✅&nbsp;&nbsp;Inference<br>
# &nbsp;&nbsp;✅&nbsp;&nbsp;Interactive Analysis & Visualization<br>
#
# <br>
#
# ### Version Notes:
# v5: Model `cascade_rcnn_r50_fpn_20e` | mAP 0.490
#
# v8: Model `cascade_rcnn_x101_32x4d_fpn_1x` | Added more augmentations | 12 epochs | mAP 0.535+
#
# <br>
#
# <span style="color: #E45D00; font-family: Segoe UI; font-size: 1.9em; font-weight: 300;">MMDetection</span>
#
# MMDetection is an open-source toolbox based on PyTorch for Object Detection and Segmentation tasks. The toolbox supports over **50+ baselines**.
#
# <span style="color: #000508; font-family: Segoe UI; font-size: 1.4em;">🧫 Features:</span>
#
# <p style='text-align: justify; font-family: Segoe UI;'><span style="color: #000508;  font-size: 1.1em; font-weight: 600;">Modular Design</span>: The framework is split into different components and we can easily construct a customized object detection framework by combining different modules.</p>
#
# <p style='text-align: justify; font-family: Segoe UI;'><span style="color: #000508;  font-size: 1.1em; font-weight: 600;">Support of multiple frameworks out of box</span>: The toolbox directly supports popular and contemporary detection frameworks, e.g. Faster RCNN, Mask RCNN, RetinaNet, etc.</p>
#
# <p style='text-align: justify; font-family: Segoe UI;'><span style="color: #000508;  font-size: 1.1em; font-weight: 600;">High efficiency</span>: All basic bbox and mask operations run on GPUs. The training speed is faster than or comparable to other codebases, including Detectron2, maskrcnn-benchmark and SimpleDet.</p>
#
# <p style='text-align: justify; font-family: Segoe UI;'><span style="color: #000508;  font-size: 1.1em; font-weight: 600;">State of the art</span>: The toolbox stems from the codebase developed by the MMDet team, who won COCO Detection Challenge in 2018.</p>
#
#
# <span style="color: #E45D00; font-family: Segoe UI; font-size: 1.9em; font-weight: 300;">Supported Backbones:</span>
#
# <table style="align:left; display:block">
# <thead>
# <tr>
# <th></th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>ResNet (CVPR'2016)</td>
# <td>RegNet (CVPR'2020)</td>
# </tr>
# <tr>
# <td>ResNeXt (CVPR'2017)</td>
# <td>Res2Net (TPAMI'2020)</td>
# </tr>
# <tr>
# <td>VGG (ICLR'2015)</td>
# <td>ResNeSt (ArXiv'2020)</td>
# </tr>
# <tr>
# <td>HRNet (CVPR'2019)</td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# <span style="color: #E45D00; font-family: Segoe UI; font-size: 1.9em; font-weight: 300; align:left">Supported Methods:</span>
#
# <table style="align:left; display:block">
# <thead>
# <tr>
# <th></th>
# <th></th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/rpn">RPN (NeurIPS'2015)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/nas_fpn">NAS-FPN (CVPR'2019)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/gfl/README.md">Generalized Focal Loss (NeurIPS'2020)</a></td>
# </tr>
# <tr>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/fast_rcnn">Fast R-CNN (ICCV'2015)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/atss">ATSS (CVPR'2020)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/cornernet/README.md">CornerNet (ECCV'2018)</a></td>
# </tr>
# <tr>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/faster_rcnn">Faster R-CNN (NeurIPS'2015)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/fsaf">FSAF (CVPR'2019)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/sabl/README.md">Side-Aware Boundary Localization (ECCV'2020)</a></td>
# </tr>
# <tr>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/mask_rcnn">Mask R-CNN (ICCV'2017)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/pafpn">PAFPN (CVPR'2018)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/yolo/README.md">YOLOv3 (ArXiv'2018)</a></td>
# </tr>
# <tr>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/cascade_rcnn">Cascade R-CNN (CVPR'2018)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/dynamic_rcnn">Dynamic R-CNN (ECCV'2020)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/paa/README.md">PAA (ECCV'2020)</a></td>
# </tr>
# <tr>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/cascade_rcnn">Cascade Mask R-CNN (CVPR'2018)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/point_rend">PointRend (CVPR'2020)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/yolact/README.md">YOLACT (ICCV'2019)</a></td>
# </tr>
# <tr>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/ssd">SSD (ECCV'2016)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/carafe/README.md">CARAFE (ICCV'2019)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/centripetalnet/README.md">CentripetalNet (CVPR'2020)</a></td>
# </tr>
# <tr>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/retinanet">RetinaNet (ICCV'2017)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/dcn/README.md">DCNv2 (CVPR'2019)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/vfnet/README.md">VFNet (ArXix'2020)</a></td>
# </tr>
# <tr>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/ghm">GHM (AAAI'2019)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/gn/README.md">Group Normalization (ECCV'2018)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/detr/README.md">DETR (ECCV'2020)</a></td>
# </tr>
# <tr>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/ms_rcnn">Mask Scoring R-CNN (CVPR'2019)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/gn+ws/README.md">Weight Standardization (ArXiv'2019)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/deformable_detr/README.md">Deformable DETR (ICLR'2021)</a></td>
# </tr>
# <tr>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/double_heads">Double-Head R-CNN (CVPR'2020)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/faster_rcnn/faster_rcnn_r50_fpn_ohem_1x_coco.py">OHEM (CVPR'2016)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/cascade_rpn/README.md">CascadeRPN (NeurIPS'2019)</a></td>
# </tr>
# <tr>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/htc">Hybrid Task Cascade (CVPR'2019)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/faster_rcnn/faster_rcnn_r50_fpn_soft_nms_1x_coco.py">Soft-NMS (ICCV'2017)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/scnet/README.md">SCNet (AAAI'2021)</a></td>
# </tr>
# <tr>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/libra_rcnn">Libra R-CNN (CVPR'2019)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/empirical_attention/README.md">Generalized Attention (ICCV'2019)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/autoassign/README.md">AutoAssign (ArXix'2020)</a></td>
# </tr>
# <tr>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/guided_anchoring">Guided Anchoring (CVPR'2019)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/gcnet/README.md">GCNet (ICCVW'2019)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/yolof/README.md">YOLOF (CVPR'2021)</a></td>
# </tr>
# <tr>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/fcos">FCOS (ICCV'2019)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/fp16/README.md">Mixed Precision (FP16) Training (ArXiv'2017)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/seesaw_loss/README.md">Seasaw Loss (CVPR'2021)</a></td>
# </tr>
# <tr>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/reppoints">RepPoints (ICCV'2019)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/instaboost/README.md">InstaBoost (ICCV'2019)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/centernet/README.md">CenterNet (CVPR'2019)</a></td>
# </tr>
# <tr>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/foveabox">Foveabox (TIP'2020)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/groie/README.md">GRoIE (ICPR'2020)</a></td>
# <td></td>
# </tr>
# <tr>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/free_anchor">FreeAnchor (NeurIPS'2019)</a></td>
# <td><a href="https://github.com/open-mmlab/mmdetection/blob/master/configs/detectors/README.md">DetectoRS (ArXix'2020)</a></td>
# <td></td>
# </tr>
# </tbody>
# </table>
#
# <br>
# <span style="color: #E45D00; font-family: Segoe UI; font-size: 1.9em; font-weight: 300; align:left">Never Lose Track of ML Models with Weights & Biases </span>
#
#
# Weights & Biases helps us build better models faster with a central dashboard for machine learning projects. It helps to log the hyperparameters, output metrics and images from runs, then visualize and compare results with ease from anywhere.
#
# It helps a lot in managing and tracking experiments during rapid prototyping and development by enabling advanced monitoring and visualization of ML processes with minimal integration effort.
#
# **As Kaggle notebooks do not allow running aditional scripts in parallel or hosting pages for logging (which is required in Tensorboard or other IPython tools), Weights & Biases seems to be the most viable option for monitoring training live, while it is in progress.**
#
# **It also provides free SaaS hosting and 100 GB storage for a single member.**
#
# <br>
#
# ![](https://i.ibb.co/ZhpRGJP/gif1.gif)
#
# <span style="color: #000508; font-family: Segoe UI; font-size: 1.4em;">Highlights:</span>
#
# <p style='text-align: justify; font-family: Segoe UI;'><span style="color: #000508;  font-size: 1.1em; font-weight: 600;">Train Anywhere</span>: The W&B dashboard is centralized - whether you're training on a local machine, lab cluster, or spot instances in the cloud, all of your results get logged to a single place.</p>
#
# <p style='text-align: justify; font-family: Segoe UI;'><span style="color: #000508;  font-size: 1.1em; font-weight: 600;">Visualize Seamlessly</span>: Add W&B's lightweight integration to your existing ML code and quickly get live metrics, terminal logs, and system stats streamed to the centralized dashboard.
# </p>
#
# <p style='text-align: justify; font-family: Segoe UI;'><span style="color: #000508;  font-size: 1.1em; font-weight: 600;">Stay Organized</span>: W&B logs data into powerful, querably tables that you can search, filter, sort, and group. This makes it easy to compare thousands of different models and find the best performing model for different tasks.</p>
#
# <p style='text-align: justify; font-family: Segoe UI;'><span style="color: #000508;  font-size: 1.1em; font-weight: 600;">Collaborate in Real-time</span>: Explain how your model works, show graphs of how model versions improved, discuss bugs, and demonstrate progress towards milestones.</p>
#
# <p style='text-align: justify; font-family: Segoe UI;'><span style="color: #000508;  font-size: 1.1em; font-weight: 600;">Designed for all use cases</span>: Never lose track of another ML project.</p>
#
# <p style='text-align: justify; font-family: Segoe UI;'><span style="color: #000508;  font-size: 1.1em; font-weight: 600;">Logged Automatically</span>: System metrics such as the CPU and GPU utilization, network, etc are shown in the System tab on the run page. For the GPU, these are fetched with nvidia-smi. The stdout and stderr from the running shell, are picked up and shown in the logs tab on the run page.</p>
#
# <br>
# <span style="color: #000508; font-family: Segoe UI; font-size: 1.4em;">📌 Useful Resources</span>
#
# <p style='text-align: justify;'><span style="color: #000508; font-family: Segoe UI; font-size: 1.2em; font-weight: 400;">Notebook on processing annotations and generating COCO Dataset:</span></p>
#
# SIIM Covid-19 Resize & Process + Coco Dataset🌀💹
#
# https://www.kaggle.com/sreevishnudamodaran/siim-covid-19-resize-process-coco-dataset
#
# <br>
# <p style='text-align: justify;'><span style="color: #000508; font-family: Segoe UI; font-size: 1.2em; font-weight: 400;">The images and the COCO Annotations used in this notebook:</span></p>
#
# SIIM covid19 512 images and metadata
#
# https://www.kaggle.com/sreevishnudamodaran/siim-covid19-512-images-and-metadata
#
# SIIM Covid-19 COCO 512x512 GroupKFold
#
# https://www.kaggle.com/sreevishnudamodaran/siim-covid19-coco-512x512-groupkfold
#
# I will update these datasets if needed, when the issues in the discussions regarding the dataset are resolved by the organizers.
#
# <br>
# <span style="color: #000508; font-family: Segoe UI; font-size: 1.4em;">🎆 References:</span>
#
# - **Some amazing notebooks on Weights and Biases from [@ayuraj](https://www.kaggle.com/ayuraj)**
#     - https://www.kaggle.com/ayuraj/visualize-bounding-boxes-interactively
#     - https://www.kaggle.com/ayuraj/train-covid-19-detection-using-yolov5
#
#
#
# - https://www.kaggle.com/sreevishnudamodaran/vinbigdata-fusing-bboxes-coco-dataset
#
# <br>
# <a href="https://www.kaggle.com/sreevishnudamodaran"><center><img border="0" alt="Ask Me Something" src="https://img.shields.io/badge/Ask%20me-something-1abc9c.svg?style=flat-square&logo=kaggle" width="130" height="10"></center></a>
# <br>
# <center><img border="0" alt="Ask Me Something" src="https://img.shields.io/badge/Please-Upvote%20If%20you%20like%20this-07b3c8?style=for-the-badge&logo=kaggle" width="260" height="20"></center>

# %% [markdown]
# <span style="color: #E45D00; font-family: Segoe UI; font-size: 1.9em; font-weight: 300;">📐 Setup MMDetection</span>

# %%
# %%bash
# # Check nvcc version
# nvcc -V
# echo
# # Check GCC version
# gcc --version
# echo
# # Check the version of torch and cuda packages
# pip list | grep "torch\|cuda"
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0
#
# gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
# Copyright (C) 2017 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
#
# cupy-cuda110                   8.6.0
# jaxlib                         0.1.64+cuda110
# nnabla-ext-cuda110             1.19.0
# pycuda                         2021.1
# pytorch-ignite                 0.4.4
# pytorch-lightning              1.2.8
# torch                          1.7.0
# torchaudio                     0.7.0a0+ac17b64
# torchmetrics                   0.2.0
# torchtext                      0.8.0a0+cd6902d
# torchvision                    0.8.1

# %%
# !pip install mmcv-full==1.3.8 -f https://download.openmmlab.com/mmcv/dist/cu110/torch1.7.0/index.html
# Out:
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu110/torch1.7.0/index.html
# Collecting mmcv-full==1.3.8
#   Downloading https://download.openmmlab.com/mmcv/dist/cu110/torch1.7.0/mmcv_full-1.3.8-cp37-cp37m-manylinux1_x86_64.whl (31.2 MB)
#      |████████████████████████████████| 31.2 MB 7.3 MB/s
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.7/site-packages (from mmcv-full==1.3.8) (7.2.0)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.7/site-packages (from mmcv-full==1.3.8) (5.3.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from mmcv-full==1.3.8) (1.19.5)
# Collecting yapf
#   Downloading yapf-0.31.0-py2.py3-none-any.whl (185 kB)
#      |████████████████████████████████| 185 kB 4.6 MB/s
# Requirement already satisfied: opencv-python>=3 in /opt/conda/lib/python3.7/site-packages (from mmcv-full==1.3.8) (4.5.1.48)
# Collecting addict
#   Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Installing collected packages: yapf, addict, mmcv-full
# Successfully installed addict-2.4.0 mmcv-full-1.3.8 yapf-0.31.0

# %%
# !rm -rf mmdetection
# !git clone https://github.com/open-mmlab/mmdetection.git
# !cd mmdetection && pip install -e .

# !pip install Pillow==7.0.0
# Out:
# Cloning into 'mmdetection'...
# remote: Enumerating objects: 19386, done.
# remote: Counting objects: 100% (317/317), done.
# remote: Compressing objects: 100% (224/224), done.
# remote: Total 19386 (delta 130), reused 208 (delta 92), pack-reused 19069
# Receiving objects: 100% (19386/19386), 23.67 MiB | 27.35 MiB/s, done.
# Resolving deltas: 100% (13524/13524), done.
# Obtaining file:///kaggle/working/mmdetection
# Collecting panopticapi@ git+https://github.com/cocodataset/panopticapi.git
#   Cloning https://github.com/cocodataset/panopticapi.git to /tmp/pip-install-uamcgw3v/panopticapi_ec65159c412b418aad0b705c322de053
#   Running command git clone -q https://github.com/cocodataset/panopticapi.git /tmp/pip-install-uamcgw3v/panopticapi_ec65159c412b418aad0b705c322de053
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.7/site-packages (from mmdet==2.14.0) (3.4.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from mmdet==2.14.0) (1.19.5)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from mmdet==2.14.0) (1.15.0)
# Requirement already satisfied: terminaltables in /opt/conda/lib/python3.7/site-packages (from mmdet==2.14.0) (3.1.0)
# Collecting pycocotools
#   Downloading pycocotools-2.0.2.tar.gz (23 kB)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.7/site-packages (from panopticapi@ git+https://github.com/cocodataset/panopticapi.git->mmdet==2.14.0) (7.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.7/site-packages (from matplotlib->mmdet==2.14.0) (2.8.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.7/site-packages (from matplotlib->mmdet==2.14.0) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->mmdet==2.14.0) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->mmdet==2.14.0) (1.3.1)
# Requirement already satisfied: setuptools>=18.0 in /opt/conda/lib/python3.7/site-packages (from pycocotools->mmdet==2.14.0) (49.6.0.post20210108)
# Requirement already satisfied: cython>=0.27.3 in /opt/conda/lib/python3.7/site-packages (from pycocotools->mmdet==2.14.0) (0.29.23)
# Building wheels for collected packages: panopticapi, pycocotools
# done
#   Created wheel for panopticapi: filename=panopticapi-0.1-py3-none-any.whl size=8318 sha256=b87c023e6b0b9f05de48284b3ee51b985b4c3a0933c1505b3967536db080ce15
#   Stored in directory: /tmp/pip-ephem-wheel-cache-yy0i55vb/wheels/ad/89/b8/b66cce9246af3d71d65d72c85ab993fd28e7578e1b0ed197f1
# done
#   Created wheel for pycocotools: filename=pycocotools-2.0.2-cp37-cp37m-linux_x86_64.whl size=272448 sha256=1e7d72195b58bf50fca3907a0eae5de120cb99b3bd850e5f5d749ebd98670737
#   Stored in directory: /root/.cache/pip/wheels/bc/cf/1b/e95c99c5f9d1648be3f500ca55e7ce55f24818b0f48336adaf
# Successfully built panopticapi pycocotools
# Installing collected packages: pycocotools, panopticapi, mmdet
#   Running setup.py develop for mmdet
# Successfully installed mmdet panopticapi-0.1 pycocotools-2.0.2
# Collecting Pillow==7.0.0
#   Downloading Pillow-7.0.0-cp37-cp37m-manylinux1_x86_64.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 4.5 MB/s
# Installing collected packages: Pillow
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.2.0
#     Uninstalling Pillow-7.2.0:
#       Successfully uninstalled Pillow-7.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bokeh 2.3.1 requires pillow>=7.1.0, but you have pillow 7.0.0 which is incompatible.
# Successfully installed Pillow-7.0.0

# %% [markdown]
# <span style="color: #E45D00; font-family: Segoe UI; font-size: 1.9em; font-weight: 300;">Setup Weights & Biases</span>

# %%
# !pip install wandb --upgrade
# Out:
# Requirement already satisfied: wandb in /opt/conda/lib/python3.7/site-packages (0.10.26)
# Collecting wandb
#   Downloading wandb-0.11.0-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 4.5 MB/s
# Requirement already satisfied: protobuf>=3.12.0 in /opt/conda/lib/python3.7/site-packages (from wandb) (3.15.8)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.7/site-packages (from wandb) (5.8.0)
# Requirement already satisfied: GitPython>=1.0.0 in /opt/conda/lib/python3.7/site-packages (from wandb) (3.1.14)
# Collecting urllib3>=1.26.5
#   Downloading urllib3-1.26.6-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 18.4 MB/s
# Requirement already satisfied: promise<3,>=2.0 in /opt/conda/lib/python3.7/site-packages (from wandb) (2.3)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.7/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: subprocess32>=3.5.3 in /opt/conda/lib/python3.7/site-packages (from wandb) (3.5.4)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /opt/conda/lib/python3.7/site-packages (from wandb) (7.1.2)
# Requirement already satisfied: six>=1.13.0 in /opt/conda/lib/python3.7/site-packages (from wandb) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/conda/lib/python3.7/site-packages (from wandb) (2.8.1)
# Requirement already satisfied: sentry-sdk>=0.4.0 in /opt/conda/lib/python3.7/site-packages (from wandb) (1.0.0)
# Requirement already satisfied: shortuuid>=0.5.0 in /opt/conda/lib/python3.7/site-packages (from wandb) (1.0.1)
# Requirement already satisfied: configparser>=3.8.1 in /opt/conda/lib/python3.7/site-packages (from wandb) (5.0.2)
# Requirement already satisfied: pathtools in /opt/conda/lib/python3.7/site-packages (from wandb) (0.1.2)
# Requirement already satisfied: PyYAML in /opt/conda/lib/python3.7/site-packages (from wandb) (5.3.1)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from wandb) (2.25.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.7/site-packages (from GitPython>=1.0.0->wandb) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in /opt/conda/lib/python3.7/site-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb) (3.0.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.0.0->wandb) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.0.0->wandb) (2020.12.5)
# Installing collected packages: urllib3, wandb
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.4
#     Uninstalling urllib3-1.26.4:
#       Successfully uninstalled urllib3-1.26.4
#   Attempting uninstall: wandb
#     Found existing installation: wandb 0.10.26
#     Uninstalling wandb-0.10.26:
#       Successfully uninstalled wandb-0.10.26
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyterlab-git 0.11.0 requires nbdime<2.0.0,>=1.1.0, but you have nbdime 2.1.0 which is incompatible.
# earthengine-api 0.1.261 requires google-api-python-client<2,>=1.12.1, but you have google-api-python-client 1.8.0 which is incompatible.
# allennlp 2.3.0 requires wandb<0.11.0,>=0.10.0, but you have wandb 0.11.0 which is incompatible.
# aiobotocore 1.3.0 requires botocore<1.20.50,>=1.20.49, but you have botocore 1.20.53 which is incompatible.
# Successfully installed urllib3-1.26.6 wandb-0.11.0

# %% [markdown]
# To connect the Kaggle Notebook and log in to Weights & Biases, we need to create an API key:
#
# 1. New users can sign up for a Free Weights & Biases account for Research and Personal use from the https://wandb.ai/site page. Sign up process takes around 1-2 minutes.
# 2. Now get the API key from https://wandb.ai/authorize.
#
# Login to Weights & Biases from the notebook with the API key by using any of the two methods below:
#
# * Interative:
#     1. Run a cell with wandb.login(). It will ask for the API key, which can be copied and pasted to authenticate.
#
# * Kaggle Secrets:
#     1. The recommended way to use the API key is to use Kaggle Secrets to store the API key. From the top Menu on the Notebook Editor, click on 'Add-ons' and then, select 'Secrets'.
#     2. Select 'Add a new secret' and provide 'wandb_key' for label and it's value as the API key obtained from the previous steps.

# %%
import wandb
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()

# I have saved my API token with "wandb_api" as Label. 
# If you use some other Label make sure to change the same below. 
wandb_api = user_secrets.get_secret("wandb_key") 

wandb.login(key=wandb_api)
# Out:
# wandb: W&B API key is configured (use `wandb login --relogin` to force relogin)
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publically.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %% [markdown]
# <span style="color: #E45D00; font-family: Segoe UI; font-size: 1.9em; font-weight: 300;">Imports and Seed Everything</span>

# %%
import sys
sys.path.insert(0, "./mmdetection")

import os
# Check Pytorch installation
import torch, torchvision
print(torch.__version__, torch.cuda.is_available())

# Check mmcv installation
from mmcv.ops import get_compiling_cuda_version, get_compiler_version
print(get_compiling_cuda_version())
print(get_compiler_version())

# Check MMDetection installation
from mmdet.apis import set_random_seed

# Imports
import mmdet
from mmdet.apis import set_random_seed
from mmdet.datasets import build_dataset
from mmdet.models import build_detector
from mmdet.apis import train_detector

import random
import numpy as np
from pathlib import Path
# Out:
# 1.7.0 True
# 11.0
# GCC 7.3

# %%
global_seed = 111

def set_seed(seed=global_seed):
    """Sets the random seeds."""
    set_random_seed(seed, deterministic=False)
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    os.environ['PYTHONHASHSEED'] = str(seed)
    
set_seed()

# %% [markdown]
# <span style="color: #E45D00; font-family: Segoe UI; font-size: 1.9em; font-weight: 300;">🔨 Prepare the MMDetection Config</span>

# %%
from mmcv import Config

# cfg = Config.fromfile('/kaggle/working/mmdetection/configs/vfnet/vfnet_r50_fpn_mdconv_c3-c5_mstrain_2x_coco.py')
# cfg = Config.fromfile("/kaggle/working/mmdetection/configs/vfnet/vfnet_r50_fpn_mstrain_2x_coco.py")
# cfg = Config.fromfile("/kaggle/working/mmdetection/configs/gfl/gfl_r50_fpn_mstrain_2x_coco.py")
# baseline_cfg_path = "/kaggle/working/mmdetection/configs/cascade_rcnn/cascade_rcnn_r50_fpn_20e_coco.py"
baseline_cfg_path = "/kaggle/working/mmdetection/configs/cascade_rcnn/cascade_rcnn_x101_32x4d_fpn_1x_coco.py"
cfg = Config.fromfile(baseline_cfg_path)

# %% [markdown]
# <span style="color: #000508; font-family: Segoe UI; font-size: 1.6em; font-weight: 300;">General Training Settings</span>

# %%
# model_name = 'vfnet_r50_fpn'
# model_name = 'cascade_rcnn_r50_fpn'
model_name = 'cascade_rcnn_x101_32x4d_fpn_1x'
fold = 0
job = 4

# Folder to store model logs and weight files
job_folder = f'/kaggle/working/job{job}_{model_name}_fold{fold}'
cfg.work_dir = job_folder

# Change the wnd username and project name below
wnb_username = 'sreevishnu-damodaran'
wnb_project_name = 'siim-covid19-1'

# Set seed thus the results are more reproducible
cfg.seed = global_seed

if not os.path.exists(job_folder):
    os.makedirs(job_folder)

print("Job folder:", job_folder)
# Out:
# Job folder: /kaggle/working/job4_cascade_rcnn_x101_32x4d_fpn_1x_fold0

# %%
# Set the number of classes
for head in cfg.model.roi_head.bbox_head:
    head.num_classes = 1
# cfg.model.roi_head.bbox_head.num_classes = 1
# cfg.model.bbox_head.num_classes = 1

# cfg.gpu_ids = range(1)
cfg.gpu_ids = [0]

# Setting pretrained model in the init_cfg which is required 
# for transfer learning as per the latest MMdetection update
cfg.model.backbone.init_cfg=dict(type='Pretrained', checkpoint='torchvision://resnet50')
cfg.model.backbone.init_cfg=dict(type='Pretrained', checkpoint='open-mmlab://resnext101_32x4d')
cfg.model.pop('pretrained', None)

cfg.runner.max_epochs = 12 # Epochs for the runner that runs the workflow 
cfg.total_epochs = 12

# Learning rate of optimizers. The LR is divided by 8 since the config file is originally for 8 GPUs
cfg.optimizer.lr = 0.02/8

## Learning rate scheduler config used to register LrUpdater hook
cfg.lr_config = dict(
    policy='CosineAnnealing', # The policy of scheduler, also support CosineAnnealing, Cyclic, etc. Refer to details of supported LrUpdater from https://github.com/open-mmlab/mmcv/blob/master/mmcv/runner/hooks/lr_updater.py#L9.
    by_epoch=False,
    warmup='linear', # The warmup policy, also support `exp` and `constant`.
    warmup_iters=500, # The number of iterations for warmup
    warmup_ratio=0.001, # The ratio of the starting learning rate used for warmup
    min_lr=1e-07)

# config to register logger hook
cfg.log_config.interval = 20 # Interval to print the log

# Config to set the checkpoint hook, Refer to https://github.com/open-mmlab/mmcv/blob/master/mmcv/runner/hooks/checkpoint.py for implementation.
cfg.checkpoint_config.interval = 1 # The save interval is 1

# %% [markdown]
# <span style="color: #000508; font-family: Segoe UI; font-size: 1.6em; font-weight: 300;">Configure Datasets for Training and Evaluation</span>

# %%
cfg.dataset_type = 'CocoDataset' # Dataset type, this will be used to define the dataset
cfg.classes = ("Covid_Abnormality",)

cfg.data.train.img_prefix = '/kaggle/input/siim-covid19-512-images-and-metadata/train' # Prefix of image path
cfg.data.train.classes = cfg.classes
cfg.data.train.ann_file = f'/kaggle/input/siim-covid19-coco-512x512-groupkfold/train_annotations_fold{fold}.json'
cfg.data.train.type='CocoDataset'

cfg.data.val.img_prefix = '/kaggle/input/siim-covid19-512-images-and-metadata/train' # Prefix of image path
cfg.data.val.classes = cfg.classes
cfg.data.val.ann_file = f'/kaggle/input/siim-covid19-coco-512x512-groupkfold/val_annotations_fold{fold}.json'
cfg.data.val.type='CocoDataset'

cfg.data.test.img_prefix = '/kaggle/input/siim-covid19-512-images-and-metadata/train' # Prefix of image path
cfg.data.test.classes = cfg.classes
cfg.data.test.ann_file =  f'/kaggle/input/siim-covid19-coco-512x512-groupkfold/val_annotations_fold{fold}.json'
cfg.data.test.type='CocoDataset'

cfg.data.samples_per_gpu = 4 # Batch size of a single GPU used in testing
cfg.data.workers_per_gpu = 2 # Worker to pre-fetch data for each single GPU

# %% [markdown]
# <span style="color: #000508; font-family: Segoe UI; font-size: 1.6em; font-weight: 300;">Setting Metric for Evaluation</span>

# %%
# The config to build the evaluation hook, refer to https://github.com/open-mmlab/mmdetection/blob/master/mmdet/core/evaluation/eval_hooks.py#L7 for more details.
cfg.evaluation.metric = 'bbox' # Metrics used during evaluation

# Set the epoch intervel to perform evaluation
cfg.evaluation.interval = 1

# Set the iou threshold of the mAP calculation during evaluation
cfg.evaluation.iou_thrs = [0.5]

# cfg.evaluation.save_best='bbox_mAP_50'

# %% [markdown]
# <span style="color: #000508; font-family: Segoe UI; font-size: 1.6em; font-weight: 300;">Prepare the Pre-processing & Augmentation Pipelines</span>

# %%
albu_train_transforms = [
    dict(type='ShiftScaleRotate', shift_limit=0.0625,
         scale_limit=0.15, rotate_limit=15, p=0.4),
    dict(type='RandomBrightnessContrast', brightness_limit=0.2,
         contrast_limit=0.2, p=0.5),
    dict(type='IAAAffine', shear=(-10.0, 10.0), p=0.4),
#     dict(type='MixUp', p=0.2, lambd=0.5),
    dict(type="Blur", p=1.0, blur_limit=7),
    dict(type='CLAHE', p=0.5),
    dict(type='Equalize', mode='cv', p=0.4),
    dict(
        type="OneOf",
        transforms=[
            dict(type="GaussianBlur", p=1.0, blur_limit=7),
            dict(type="MedianBlur", p=1.0, blur_limit=7),
        ],
        p=0.4,
    ),
    
#     dict(type='MixUp', p=0.2, lambd=0.5),
#     dict(type='RandomRotate90', p=0.5),
#     dict(type='CLAHE', p=0.5),
#     dict(type='InvertImg', p=0.5),
#     dict(type='Equalize', mode='cv', p=0.4),
#     dict(type='MedianBlur', blur_limit=3, p=0.1)
    ]


cfg.train_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
    dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
    dict(type='RandomFlip', flip_ratio=0.5),
    dict(
        type='Albu',
        transforms=albu_train_transforms,
        bbox_params=dict(
        type='BboxParams',
        format='pascal_voc',
        label_fields=['gt_labels'],
        min_visibility=0.0,
        filter_lost_elements=True),
        keymap=dict(img='image', gt_bboxes='bboxes'),
        update_pad_shape=False,
        skip_img_without_anno=True),
    dict(
        type='Normalize',
        mean=[123.675, 116.28, 103.53],
        std=[58.395, 57.12, 57.375],
        to_rgb=True),
    dict(type='Pad', size_divisor=32),
    dict(type='DefaultFormatBundle'),
    dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels', 'gt_masks'])
]
cfg.test_pipeline = [
    dict(type='LoadImageFromFile'),
    dict(
        type='MultiScaleFlipAug',
        img_scale=(1333, 800),
        flip=False,
        transforms=[
            dict(type='Resize', keep_ratio=True),
            dict(type='RandomFlip'),
            dict(
                type='Normalize',
                mean=[123.675, 116.28, 103.53],
                std=[58.395, 57.12, 57.375],
                to_rgb=True),
            dict(type='Pad', size_divisor=32),
            dict(type='ImageToTensor', keys=['img']),
            dict(type='Collect', keys=['img'])
        ])
]

# %% [markdown]
# <span style="color: #000508; font-family: Segoe UI; font-size: 1.6em; font-weight: 300;">Weights & Biases Integration for Experiment Tracking and Logging</span>

# %%
## 4, 8
# cfg.log_level = 'DEBUG'
cfg.log_config.hooks = [dict(type='TextLoggerHook'),
                        dict(type='WandbLoggerHook',
                             init_kwargs=dict(project=wnb_project_name,
                                              name=f'exp-{model_name}-fold{fold}-job{job}',
                                              entity=wnb_username))
                       ]

# %% [markdown]
# <span style="color: #000508; font-family: Segoe UI; font-size: 1.6em; font-weight: 300;">Save Config File</span>

# %%
cfg_path = f'{job_folder}/job{job}_{Path(baseline_cfg_path).name}'
print(cfg_path)

# Save config file for inference later
cfg.dump(cfg_path)
print(f'Config:\n{cfg.pretty_text}')
# Out:
# /kaggle/working/job4_cascade_rcnn_x101_32x4d_fpn_1x_fold0/job4_cascade_rcnn_x101_32x4d_fpn_1x_coco.py
# Config:
# model = dict(
#     type='CascadeRCNN',
#     backbone=dict(
#         type='ResNeXt',
#         depth=101,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=True,
#         style='pytorch',
#         init_cfg=dict(
#             type='Pretrained', checkpoint='open-mmlab://resnext101_32x4d'),
#         groups=32,
#         base_width=4),
#     neck=dict(
#         type='FPN',
#         in_channels=[256, 512, 1024, 2048],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[8],
#             ratios=[0.5, 1.0, 2.0],
#             strides=[4, 8, 16, 32, 64]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[0.0, 0.0, 0.0, 0.0],
#             target_stds=[1.0, 1.0, 1.0, 1.0]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(
#             type='SmoothL1Loss', beta=0.1111111111111111, loss_weight=1.0)),
#     roi_head=dict(
#         type='CascadeRoIHead',
#         num_stages=3,
#         stage_loss_weights=[1, 0.5, 0.25],
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[4, 8, 16, 32]),
#         bbox_head=[
#             dict(
#                 type='Shared2FCBBoxHead',
#                 in_channels=256,
#                 fc_out_channels=1024,
#                 roi_feat_size=7,
#                 num_classes=1,
#                 bbox_coder=dict(
#                     type='DeltaXYWHBBoxCoder',
#                     target_means=[0.0, 0.0, 0.0, 0.0],
#                     target_stds=[0.1, 0.1, 0.2, 0.2]),
#                 reg_class_agnostic=True,
#                 loss_cls=dict(
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False,
#                     loss_weight=1.0),
#                 loss_bbox=dict(type='SmoothL1Loss', beta=1.0,
#                                loss_weight=1.0)),
#             dict(
#                 type='Shared2FCBBoxHead',
#                 in_channels=256,
#                 fc_out_channels=1024,
#                 roi_feat_size=7,
#                 num_classes=1,
#                 bbox_coder=dict(
#                     type='DeltaXYWHBBoxCoder',
#                     target_means=[0.0, 0.0, 0.0, 0.0],
#                     target_stds=[0.05, 0.05, 0.1, 0.1]),
#                 reg_class_agnostic=True,
#                 loss_cls=dict(
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False,
#                     loss_weight=1.0),
#                 loss_bbox=dict(type='SmoothL1Loss', beta=1.0,
#                                loss_weight=1.0)),
#             dict(
#                 type='Shared2FCBBoxHead',
#                 in_channels=256,
#                 fc_out_channels=1024,
#                 roi_feat_size=7,
#                 num_classes=1,
#                 bbox_coder=dict(
#                     type='DeltaXYWHBBoxCoder',
#                     target_means=[0.0, 0.0, 0.0, 0.0],
#                     target_stds=[0.033, 0.033, 0.067, 0.067]),
#                 reg_class_agnostic=True,
#                 loss_cls=dict(
#                     type='CrossEntropyLoss',
#                     use_sigmoid=False,
#                     loss_weight=1.0),
#                 loss_bbox=dict(type='SmoothL1Loss', beta=1.0, loss_weight=1.0))
#         ]),
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=0,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=2000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=[
#             dict(
#                 assigner=dict(
#                     type='MaxIoUAssigner',
#                     pos_iou_thr=0.5,
#                     neg_iou_thr=0.5,
#                     min_pos_iou=0.5,
#                     match_low_quality=False,
#                     ignore_iof_thr=-1),
#                 sampler=dict(
#                     type='RandomSampler',
#                     num=512,
#                     pos_fraction=0.25,
#                     neg_pos_ub=-1,
#                     add_gt_as_proposals=True),
#                 pos_weight=-1,
#                 debug=False),
#             dict(
#                 assigner=dict(
#                     type='MaxIoUAssigner',
#                     pos_iou_thr=0.6,
#                     neg_iou_thr=0.6,
#                     min_pos_iou=0.6,
#                     match_low_quality=False,
#                     ignore_iof_thr=-1),
#                 sampler=dict(
#                     type='RandomSampler',
#                     num=512,
#                     pos_fraction=0.25,
#                     neg_pos_ub=-1,
#                     add_gt_as_proposals=True),
#                 pos_weight=-1,
#                 debug=False),
#             dict(
#                 assigner=dict(
#                     type='MaxIoUAssigner',
#                     pos_iou_thr=0.7,
#                     neg_iou_thr=0.7,
#                     min_pos_iou=0.7,
#                     match_low_quality=False,
#                     ignore_iof_thr=-1),
#                 sampler=dict(
#                     type='RandomSampler',
#                     num=512,
#                     pos_fraction=0.25,
#                     neg_pos_ub=-1,
#                     add_gt_as_proposals=True),
#                 pos_weight=-1,
#                 debug=False)
#         ]),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=1000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=100)))
# dataset_type = 'CocoDataset'
# data_root = 'data/coco/'
# img_norm_cfg = dict(
#     mean=[123.675, 116.28, 103.53], std=[58.395, 57.12, 57.375], to_rgb=True)
# train_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(type='LoadAnnotations', with_bbox=True, with_mask=True),
#     dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#     dict(type='RandomFlip', flip_ratio=0.5),
#     dict(
#         type='Albu',
#         transforms=[
#             dict(
#                 type='ShiftScaleRotate',
#                 shift_limit=0.0625,
#                 scale_limit=0.15,
#                 rotate_limit=15,
#                 p=0.4),
#             dict(
#                 type='RandomBrightnessContrast',
#                 brightness_limit=0.2,
#                 contrast_limit=0.2,
#                 p=0.5),
#             dict(type='IAAAffine', shear=(-10.0, 10.0), p=0.4),
#             dict(type='Blur', p=1.0, blur_limit=7),
#             dict(type='CLAHE', p=0.5),
#             dict(type='Equalize', mode='cv', p=0.4),
#             dict(
#                 type='OneOf',
#                 transforms=[
#                     dict(type='GaussianBlur', p=1.0, blur_limit=7),
#                     dict(type='MedianBlur', p=1.0, blur_limit=7)
#                 ],
#                 p=0.4)
#         ],
#         bbox_params=dict(
#             type='BboxParams',
#             format='pascal_voc',
#             label_fields=['gt_labels'],
#             min_visibility=0.0,
#             filter_lost_elements=True),
#         keymap=dict(img='image', gt_bboxes='bboxes'),
#         update_pad_shape=False,
#         skip_img_without_anno=True),
#     dict(
#         type='Normalize',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         to_rgb=True),
#     dict(type='Pad', size_divisor=32),
#     dict(type='DefaultFormatBundle'),
#     dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels', 'gt_masks'])
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile'),
#     dict(
#         type='MultiScaleFlipAug',
#         img_scale=(1333, 800),
#         flip=False,
#         transforms=[
#             dict(type='Resize', keep_ratio=True),
#             dict(type='RandomFlip'),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size_divisor=32),
#             dict(type='ImageToTensor', keys=['img']),
#             dict(type='Collect', keys=['img'])
#         ])
# ]
# data = dict(
#     samples_per_gpu=4,
#     workers_per_gpu=2,
#     train=dict(
#         type='CocoDataset',
#         ann_file=
#         '/kaggle/input/siim-covid19-coco-512x512-groupkfold/train_annotations_fold0.json',
#         img_prefix='/kaggle/input/siim-covid19-512-images-and-metadata/train',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(type='Resize', img_scale=(1333, 800), keep_ratio=True),
#             dict(type='RandomFlip', flip_ratio=0.5),
#             dict(
#                 type='Normalize',
#                 mean=[123.675, 116.28, 103.53],
#                 std=[58.395, 57.12, 57.375],
#                 to_rgb=True),
#             dict(type='Pad', size_divisor=32),
#             dict(type='DefaultFormatBundle'),
#             dict(type='Collect', keys=['img', 'gt_bboxes', 'gt_labels'])
#         ],
#         classes=('Covid_Abnormality', )),
#     val=dict(
#         type='CocoDataset',
#         ann_file=
#         '/kaggle/input/siim-covid19-coco-512x512-groupkfold/val_annotations_fold0.json',
#         img_prefix='/kaggle/input/siim-covid19-512-images-and-metadata/train',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ],
#         classes=('Covid_Abnormality', )),
#     test=dict(
#         type='CocoDataset',
#         ann_file=
#         '/kaggle/input/siim-covid19-coco-512x512-groupkfold/val_annotations_fold0.json',
#         img_prefix='/kaggle/input/siim-covid19-512-images-and-metadata/train',
#         pipeline=[
#             dict(type='LoadImageFromFile'),
#             dict(
#                 type='MultiScaleFlipAug',
#                 img_scale=(1333, 800),
#                 flip=False,
#                 transforms=[
#                     dict(type='Resize', keep_ratio=True),
#                     dict(type='RandomFlip'),
#                     dict(
#                         type='Normalize',
#                         mean=[123.675, 116.28, 103.53],
#                         std=[58.395, 57.12, 57.375],
#                         to_rgb=True),
#                     dict(type='Pad', size_divisor=32),
#                     dict(type='ImageToTensor', keys=['img']),
#                     dict(type='Collect', keys=['img'])
#                 ])
#         ],
#         classes=('Covid_Abnormality', )))
# evaluation = dict(interval=1, metric='bbox', iou_thrs=[0.5])
# optimizer = dict(type='SGD', lr=0.0025, momentum=0.9, weight_decay=0.0001)
# optimizer_config = dict(grad_clip=None)
# lr_config = dict(
#     policy='CosineAnnealing',
#     by_epoch=False,
#     warmup='linear',
#     warmup_iters=500,
#     warmup_ratio=0.001,
#     min_lr=1e-07)
# runner = dict(type='EpochBasedRunner', max_epochs=12)
# checkpoint_config = dict(interval=1)
# log_config = dict(
#     interval=20,
#     hooks=[
#         dict(type='TextLoggerHook'),
#         dict(
#             type='WandbLoggerHook',
#             init_kwargs=dict(
#                 project='siim-covid19-1',
#                 name='exp-cascade_rcnn_x101_32x4d_fpn_1x-fold0-job4',
#                 entity='sreevishnu-damodaran'))
#     ])
# custom_hooks = [dict(type='NumClassCheckHook')]
# dist_params = dict(backend='nccl')
# log_level = 'INFO'
# load_from = None
# resume_from = None
# workflow = [('train', 1)]
# work_dir = '/kaggle/working/job4_cascade_rcnn_x101_32x4d_fpn_1x_fold0'
# seed = 111
# gpu_ids = [0]
# total_epochs = 12
# classes = ('Covid_Abnormality', )

# %% [markdown]
# <span style="color: #E45D00; font-family: Segoe UI; font-size: 1.9em; font-weight: 300;">🚀 Build Dataset and Start Training</span>

# %%
model = build_detector(cfg.model,
                       train_cfg=cfg.get('train_cfg'),
                       test_cfg=cfg.get('test_cfg'))
model.init_weights()
# Out:
# ./mmdetection/mmdet/core/anchor/builder.py:16: UserWarning: ``build_anchor_generator`` would be deprecated soon, please use ``build_prior_generator``
#   '``build_anchor_generator`` would be deprecated soon, please use '
# 2021-07-17 07:10:08,989 - mmcv - INFO - load model from: open-mmlab://resnext101_32x4d
# 2021-07-17 07:10:08,991 - mmcv - INFO - Use load_from_openmmlab loader
# Downloading: "https://download.openmmlab.com/pretrain/third_party/resnext101_32x4d-a5af3160.pth" to /root/.cache/torch/hub/checkpoints/resnext101_32x4d-a5af3160.pth
#   0%|          | 0.00/161M [00:00<?, ?B/s]

# %%
datasets = [build_dataset(cfg.data.train)]
# Out:
# loading annotations into memory...
# Done (t=0.07s)
# creating index...
# index created!

# %% [markdown]
# <span style="font-size: 1.3em; font-weight: 300;">📌 Visit the Run page link in the cell below Ex: "https://wandb.ai/sreevishnu-damodaran/siim-covid19-1/runs/<run-id\>" as soon as the training starts to see the metrics live seamlessly in the Weights & Biases Dashboard.</span>
#
# <span style="font-size: 1.3em; font-weight: 300;">The projects page <a href="https://wandb.ai/sreevishnu-damodaran/siim-covid19-1">https://wandb.ai/sreevishnu-damodaran/siim-covid19-1</a> compares it with other training jobs.</span>

# %%
train_detector(model, datasets[0], cfg, distributed=False, validate=True)
# Out:
# 2021-07-17 07:10:35,728 - mmdet - INFO - Start running, host: root@6d93d3a2a52f, work_dir: /kaggle/working/job4_cascade_rcnn_x101_32x4d_fpn_1x_fold0
# 2021-07-17 07:10:35,729 - mmdet - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) CosineAnnealingLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (NORMAL      ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) WandbLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) CosineAnnealingLrUpdaterHook
# (NORMAL      ) EvalHook
# (NORMAL      ) NumClassCheckHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) WandbLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) CosineAnnealingLrUpdaterHook
# (NORMAL      ) EvalHook
# (LOW         ) IterTimerHook
#  --------------------
# after_train_iter:
# (ABOVE_NORMAL) OptimizerHook
# (NORMAL      ) CheckpointHook
# (NORMAL      ) EvalHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) WandbLoggerHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) CheckpointHook
# (NORMAL      ) EvalHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) WandbLoggerHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) NumClassCheckHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) WandbLoggerHook
#  --------------------
# before_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_epoch:
# (VERY_LOW    ) TextLoggerHook
# (VERY_LOW    ) WandbLoggerHook
#  --------------------
# after_run:
# (VERY_LOW    ) WandbLoggerHook
#  --------------------
# 2021-07-17 07:10:35,732 - mmdet - INFO - workflow: [('train', 1)], max: 12 epochs
# wandb: Currently logged in as: sreevishnu-damodaran (use `wandb login --relogin` to force relogin)
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
#                 Tracking run with wandb version 0.11.0<br/>
#                 Syncing run <strong style="color:#cdcd00">exp-cascade_rcnn_x101_32x4d_fpn_1x-fold0-job4</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/sreevishnu-damodaran/siim-covid19-1" target="_blank">https://wandb.ai/sreevishnu-damodaran/siim-covid19-1</a><br/>
#                 Run page: <a href="https://wandb.ai/sreevishnu-damodaran/siim-covid19-1/runs/l9ojrenr" target="_blank">https://wandb.ai/sreevishnu-damodaran/siim-covid19-1/runs/l9ojrenr</a><br/>
#                 Run data is saved locally in <code>/kaggle/working/wandb/run-20210717_071035-l9ojrenr</code><br/><br/>
# ./mmdetection/mmdet/core/anchor/anchor_generator.py:323: UserWarning: ``grid_anchors`` would be deprecated soon. Please use ``grid_priors``
#   warnings.warn('``grid_anchors`` would be deprecated soon. '
# ./mmdetection/mmdet/core/anchor/anchor_generator.py:360: UserWarning: ``single_level_grid_anchors`` would be deprecated soon. Please use ``single_level_grid_priors``
#   '``single_level_grid_anchors`` would be deprecated soon. '
# 2021-07-17 07:11:19,755 - mmdet - INFO - Epoch [1][20/859]	lr: 9.740e-05, eta: 5:24:02, time: 1.890, data_time: 0.127, memory: 8205, loss_rpn_cls: 0.6782, loss_rpn_bbox: 0.0107, s0.loss_cls: 0.1157, s0.acc: 98.7915, s0.loss_bbox: 0.0196, s1.loss_cls: 0.1360, s1.acc: 89.9243, s1.loss_bbox: 0.0083, s2.loss_cls: 0.2314, s2.acc: 47.2974, s2.loss_bbox: 0.0014, loss: 1.2013
# 2021-07-17 07:11:54,190 - mmdet - INFO - Epoch [1][40/859]	lr: 1.973e-04, eta: 5:09:02, time: 1.722, data_time: 0.011, memory: 8205, loss_rpn_cls: 0.6085, loss_rpn_bbox: 0.0115, s0.loss_cls: 0.0521, s0.acc: 98.6743, s0.loss_bbox: 0.0319, s1.loss_cls: 0.0203, s1.acc: 99.1602, s1.loss_bbox: 0.0137, s2.loss_cls: 0.0183, s2.acc: 96.6431, s2.loss_bbox: 0.0028, loss: 0.7590
# 2021-07-17 07:12:29,291 - mmdet - INFO - Epoch [1][60/859]	lr: 2.972e-04, eta: 5:05:32, time: 1.755, data_time: 0.011, memory: 8206, loss_rpn_cls: 0.2653, loss_rpn_bbox: 0.0121, s0.loss_cls: 0.0858, s0.acc: 97.9663, s0.loss_bbox: 0.0550, s1.loss_cls: 0.0307, s1.acc: 99.0405, s1.loss_bbox: 0.0175, s2.loss_cls: 0.0114, s2.acc: 99.3555, s2.loss_bbox: 0.0060, loss: 0.4838
data_time: 0.011, memory: 8206, loss_rpn_cls: 0.0180, loss_rpn_bbox: 0.0082, s0.loss_cls: 0.1221, s0.acc: 95.2661, s0.loss_bbox: 0.0960, s1.loss_cls: 0.0597, s1.acc: 95.1074, s1.loss_bbox: 0.0922, s2.loss_cls: 0.0225, s2.acc: 96.8726, s2.loss_bbox: 0.0306, loss: 0.4492
# 2021-07-17 07:33:15,101 - mmdet - INFO - Epoch [1][760/859]	lr: 2.467e-03, eta: 4:43:19, time: 1.805, data_time: 0.011, memory: 8206, loss_rpn_cls: 0.0250, loss_rpn_bbox: 0.0075, s0.loss_cls: 0.1438, s0.acc: 95.2515, s0.loss_bbox: 0.1037, s1.loss_cls: 0.0612, s1.acc: 95.6934, s1.loss_bbox: 0.0771, s2.loss_cls: 0.0195, s2.acc: 97.7173, s2.loss_bbox: 0.0206, loss: 0.4584
# 2021-07-17 07:33:50,710 - mmdet - INFO - Epoch [1][780/859]	lr: 2.465e-03, eta: 4:42:44, time: 1.780, data_time: 0.012, memory: 8206, loss_rpn_cls: 0.0256, loss_rpn_bbox: 0.0088, s0.loss_cls: 0.1236, s0.acc: 95.4468, s0.loss_bbox: 0.0964, s1.loss_cls: 0.0579, s1.acc: 95.5029, s1.loss_bbox: 0.0843, s2.loss_cls: 0.0211, s2.acc: 97.2778, s2.loss_bbox: 0.0268, loss: 0.4445
# 2021-07-17 07:34:26,601 - mmdet - INFO - Epoch [1][800/859]	lr: 2.463e-03, eta: 4:42:11, time: 1.795, data_time: 0.011, memory: 8206, loss_rpn_cls: 0.0201, loss_rpn_bbox: 0.0096, s0.loss_cls: 0.1229, s0.acc: 95.5273, s0.loss_bbox: 0.0990, s1.loss_cls: 0.0568, s1.acc: 95.6714, s1.loss_bbox: 0.0827, s2.loss_cls: 0.0209, s2.acc: 96.8970, s2.loss_bbox: 0.0275, loss: 0.4396
# 2021-07-17 07:35:02,337 - mmdet - INFO - Epoch [1][820/859]	lr: 2.461e-03, eta: 4:41:37, time: 1.787, data_time: 0.011, memory: 8206, loss_rpn_cls: 0.0227, loss_rpn_bbox: 0.0112, s0.loss_cls: 0.1250, s0.acc: 95.4443, s0.loss_bbox: 0.0992, s1.loss_cls: 0.0604, s1.acc: 95.5054, s1.loss_bbox: 0.0851, s2.loss_cls: 0.0214, s2.acc: 97.1802, s2.loss_bbox: 0.0258, loss: 0.4508
# 2021-07-17 07:35:38,454 - mmdet - INFO - Epoch [1][840/859]	lr: 2.459e-03, eta: 4:41:07, time: 1.806, data_time: 0.012, memory: 8206, loss_rpn_cls: 0.0183, loss_rpn_bbox: 0.0079, s0.loss_cls: 0.1258, s0.acc: 95.4590, s0.loss_bbox: 0.1000, s1.loss_cls: 0.0608, s1.acc: 95.4248, s1.loss_bbox: 0.0834, s2.loss_cls: 0.0218, s2.acc: 97.1021, s2.loss_bbox: 0.0266, loss: 0.4448
# 2021-07-17 07:36:12,713 - mmdet - INFO - Saving checkpoint at 1 epochs
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 858/858, 5.9 task/s, elapsed: 146s, ETA:     0s
# 2021-07-17 07:38:40,994 - mmdet - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# 2021-07-17 07:38:41,642 - mmdet - INFO - Epoch(val) [1][858]	bbox_mAP: 0.4180, bbox_mAP_50: -1.0000, bbox_mAP_75: -1.0000, bbox_mAP_s: 0.0000, bbox_mAP_m: 0.1860, bbox_mAP_l: 0.4950, bbox_mAP_copypaste: 0.418 -1.000 -1.000 0.000 0.186 0.495
# DONE (t=0.46s).
# Accumulating evaluation results...
# DONE (t=0.10s).
#  Average Precision  (AP) @[ IoU=0.50:0.50 | area=   all | maxDets=100 ] = 0.418
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.50 | area= small | maxDets=1000 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.50 | area=medium | maxDets=1000 ] = 0.186
#  Average Precision  (AP) @[ IoU=0.50:0.50 | area= large | maxDets=1000 ] = 0.495
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area=   all | maxDets=100 ] = 0.765
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area=   all | maxDets=300 ] = 0.765
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area=   all | maxDets=1000 ] = 0.765
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area= small | maxDets=1000 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area=medium | maxDets=1000 ] = 0.364
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area= large | maxDets=1000 ] = 0.872
# 2021-07-17 07:39:19,992 - mmdet - INFO - Epoch [2][20/859]	lr: 2.456e-03, eta: 4:34:23, time: 1.916, data_time: 0.125, memory: 8206, loss_rpn_cls: 0.0205, loss_rpn_bbox: 0.0083, s0.loss_cls: 0.1216, s0.acc: 95.5322, s0.loss_bbox: 0.0994, s1.loss_cls: 0.0610, s1.acc: 95.5176, s1.loss_bbox: 0.0886, s2.loss_cls: 0.0218, s2.acc: 97.1484, s2.loss_bbox: 0.0267, loss: 0.4478
# 2021-07-17 07:39:55,808 - mmdet - INFO - Epoch [2][40/859]	lr: 2.453e-03, eta: 4:33:58, time: 1.791, data_time: 0.011, memory: 8206, loss_rpn_cls: 0.0210, loss_rpn_bbox: 0.0074, s0.loss_cls: 0.1267, s0.acc: 95.6372, s0.loss_bbox: 0.0966, s1.loss_cls: 0.0557, s1.acc: 95.8325, s1.loss_bbox: 0.0771, s2.loss_cls: 0.0201, s2.acc: 97.3364, s2.loss_bbox: 0.0245, loss: 0.4291
# 2021-07-17 07:40:31,813 - mmdet - INFO - Epoch [2][60/859]	lr: 2.451e-03, eta: 4:33:34, time: 1.800, data_time: 0.011, memory: 8206, loss_rpn_cls: 0.0162, loss_rpn_bbox: 0.0088, s0.loss_cls: 0.1338, s0.acc: 94.9438, s0.loss_bbox: 0.1086, s1.loss_cls: 0.0680, s1.acc: 94.5996, s1.loss_bbox: 0.0986, s2.loss_cls: 0.0247, s2.acc: 96.7285, s2.loss_bbox: 0.0324, loss: 0.4911
# 2021-07-17 07:41:08,210 - mmdet - INFO - Epoch [2][80/859]	lr: 2.449e-03, eta: 4:33:13, time: 1.820, data_time: 0.013, memory: 8206, loss_rpn_cls: 0.0169, loss_rpn_bbox: 0.0067, s0.loss_cls: 0.1269, s0.acc: 95.3149, s0.loss_bbox: 0.0964, s1.loss_cls: 0.0607, s1.acc: 95.2832, s1.loss_bbox: 0.0855, s2.loss_cls: 0.0213, s2.acc: 97.2266, s2.loss_bbox: 0.0259, loss: 0.4402
# 2021-07-17 07:41:44,367 - mmdet - INFO - Epoch [2][100/859]	lr: 2.447e-03, eta: 4:32:49, time: 1.808, data_time: 0.011, memory: 8206, loss_rpn_cls: 0.0191, loss_rpn_bbox: 0.0083, s0.loss_cls: 0.1246, s0.acc: 95.2954, s0.loss_bbox: 0.1033, s1.loss_cls: 0.0597, s1.acc: 95.0928, s1.loss_bbox: 0.0935, s2.loss_cls: 0.0222, s2.acc: 96.6919, s2.loss_bbox: 0.0295, loss: 0.4602
# 2021-07-17 07:42:20,318 - mmdet - INFO - Epoch [2][120/859]	lr: 2.445e-03, eta: 4:32:23, time: 1.798, data_time: 0.011, memory: 8206, loss_rpn_cls: 0.0166, loss_rpn_bbox: 0.0074, s0.loss_cls: 0.1308, s0.acc: 95.2563, s0.loss_bbox: 0.1030, s1.loss_cls: 0.0583, s1.acc: 95.7788, s1.loss_bbox: 0.0785, s2.loss_cls: 0.0193, s2.acc: 97.5781, s2.loss_bbox: 0.0224, loss: 0.4364
data_time: 0.011, memory: 8207, loss_rpn_cls: 0.0174, loss_rpn_bbox: 0.0099, s0.loss_cls: 0.1197, s0.acc: 95.3613, s0.loss_bbox: 0.0969, s1.loss_cls: 0.0616, s1.acc: 94.9536, s1.loss_bbox: 0.0900, s2.loss_cls: 0.0225, s2.acc: 96.9946, s2.loss_bbox: 0.0283, loss: 0.4463
# 2021-07-17 08:03:59,741 - mmdet - INFO - Epoch [2][840/859]	lr: 2.336e-03, eta: 4:14:35, time: 1.798, data_time: 0.012, memory: 8207, loss_rpn_cls: 0.0190, loss_rpn_bbox: 0.0085, s0.loss_cls: 0.1325, s0.acc: 95.2783, s0.loss_bbox: 0.0968, s1.loss_cls: 0.0636, s1.acc: 95.2734, s1.loss_bbox: 0.0879, s2.loss_cls: 0.0240, s2.acc: 96.7041, s2.loss_bbox: 0.0314, loss: 0.4637
# 2021-07-17 08:04:34,021 - mmdet - INFO - Saving checkpoint at 2 epochs
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 858/858, 5.8 task/s, elapsed: 148s, ETA:     0s
# 2021-07-17 08:07:04,818 - mmdet - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.03s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# 2021-07-17 08:07:05,703 - mmdet - INFO - Epoch(val) [2][858]	bbox_mAP: 0.4930, bbox_mAP_50: -1.0000, bbox_mAP_75: -1.0000, bbox_mAP_s: 0.0000, bbox_mAP_m: 0.1920, bbox_mAP_l: 0.5760, bbox_mAP_copypaste: 0.493 -1.000 -1.000 0.000 0.192 0.576
# DONE (t=0.62s).
# Accumulating evaluation results...
# DONE (t=0.14s).
#  Average Precision  (AP) @[ IoU=0.50:0.50 | area=   all | maxDets=100 ] = 0.493
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.50 | area= small | maxDets=1000 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.50 | area=medium | maxDets=1000 ] = 0.192
#  Average Precision  (AP) @[ IoU=0.50:0.50 | area= large | maxDets=1000 ] = 0.576
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area=   all | maxDets=100 ] = 0.863
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area=   all | maxDets=300 ] = 0.863
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area=   all | maxDets=1000 ] = 0.863
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area= small | maxDets=1000 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area=medium | maxDets=1000 ] = 0.556
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area= large | maxDets=1000 ] = 0.947
# 2021-07-17 08:07:43,963 - mmdet - INFO - Epoch [3][20/859]	lr: 2.329e-03, eta: 4:10:53, time: 1.912, data_time: 0.125, memory: 8207, loss_rpn_cls: 0.0182, loss_rpn_bbox: 0.0077, s0.loss_cls: 0.1243, s0.acc: 95.1831, s0.loss_bbox: 0.1097, s1.loss_cls: 0.0652, s1.acc: 94.6167, s1.loss_bbox: 0.1002, s2.loss_cls: 0.0249, s2.acc: 96.3794, s2.loss_bbox: 0.0338, loss: 0.4839
# 2021-07-17 08:08:19,969 - mmdet - INFO - Epoch [3][40/859]	lr: 2.325e-03, eta: 4:10:22, time: 1.800, data_time: 0.011, memory: 8207, loss_rpn_cls: 0.0147, loss_rpn_bbox: 0.0089, s0.loss_cls: 0.1187, s0.acc: 95.5615, s0.loss_bbox: 0.0946, s1.loss_cls: 0.0596, s1.acc: 95.3003, s1.loss_bbox: 0.0888, s2.loss_cls: 0.0227, s2.acc: 96.5161, s2.loss_bbox: 0.0311, loss: 0.4392
# 2021-07-17 08:08:56,150 - mmdet - INFO - Epoch [3][60/859]	lr: 2.321e-03, eta: 4:09:52, time: 1.809, data_time: 0.013, memory: 8207, loss_rpn_cls: 0.0134, loss_rpn_bbox: 0.0081, s0.loss_cls: 0.1185, s0.acc: 95.4932, s0.loss_bbox: 0.0940, s1.loss_cls: 0.0615, s1.acc: 95.1343, s1.loss_bbox: 0.0908, s2.loss_cls: 0.0236, s2.acc: 96.8604, s2.loss_bbox: 0.0310, loss: 0.4408
# 2021-07-17 08:09:32,395 - mmdet - INFO - Epoch [3][80/859]	lr: 2.317e-03, eta: 4:09:22, time: 1.812, data_time: 0.011, memory: 8207, loss_rpn_cls: 0.0146, loss_rpn_bbox: 0.0071, s0.loss_cls: 0.1212, s0.acc: 95.2954, s0.loss_bbox: 0.1023, s1.loss_cls: 0.0619, s1.acc: 94.9316, s1.loss_bbox: 0.1006, s2.loss_cls: 0.0233, s2.acc: 96.4819, s2.loss_bbox: 0.0328, loss: 0.4639
# 2021-07-17 08:10:08,471 - mmdet - INFO - Epoch [3][100/859]	lr: 2.313e-03, eta: 4:08:51, time: 1.804, data_time: 0.011, memory: 8207, loss_rpn_cls: 0.0192, loss_rpn_bbox: 0.0091, s0.loss_cls: 0.1255, s0.acc: 95.2954, s0.loss_bbox: 0.1023, s1.loss_cls: 0.0633, s1.acc: 95.1465, s1.loss_bbox: 0.0964, s2.loss_cls: 0.0234, s2.acc: 96.7456, s2.loss_bbox: 0.0312, loss: 0.4703
# 2021-07-17 08:10:44,555 - mmdet - INFO - Epoch [3][120/859]	lr: 2.309e-03, eta: 4:08:20, time: 1.804, data_time: 0.011, memory: 8207, loss_rpn_cls: 0.0118, loss_rpn_bbox: 0.0065, s0.loss_cls: 0.1204, s0.acc: 95.5420, s0.loss_bbox: 0.0940, s1.loss_cls: 0.0596, s1.acc: 95.1318, s1.loss_bbox: 0.0905, s2.loss_cls: 0.0236, s2.acc: 96.4600, s2.loss_bbox: 0.0321, loss: 0.4385
# 2021-07-17 08:11:20,718 - mmdet - INFO - Epoch [3][140/859]	lr: 2.305e-03, eta: 4:07:49, time: 1.808, data_time: 0.011, memory: 8207, loss_rpn_cls: 0.0125, loss_rpn_bbox: 0.0082, s0.loss_cls: 0.1287, s0.acc: 95.0220, s0.loss_bbox: 0.1075, s1.loss_cls: 0.0649, s1.acc: 94.9048, s1.loss_bbox: 0.0967, s2.loss_cls: 0.0243, s2.acc: 96.5356, s2.loss_bbox: 0.0318, loss: 0.4745
# 2021-07-17 08:11:56,531 - mmdet - INFO - Epoch [3][160/859]	lr: 2.301e-03, eta: 4:07:17, time: 1.791, data_time: 0.011, memory: 8207, loss_rpn_cls: 0.0172, loss_rpn_bbox: 0.0081, s0.loss_cls: 0.1317, s0.acc: 94.9780, s0.loss_bbox: 0.1055, s1.loss_cls: 0.0655, s1.acc: 94.7974, s1.loss_bbox: 0.0993, s2.loss_cls: 0.0241, s2.acc: 96.5601, s2.loss_bbox: 0.0325, loss: 0.4838
# 2021-07-17 08:12:32,718 - mmdet - INFO - Epoch [3][180/859]	lr: 2.297e-03, eta: 4:06:46, time: 1.809, data_time: 0.012, memory: 8207, loss_rpn_cls: 0.0143, loss_rpn_bbox: 0.0073, s0.loss_cls: 0.1225, s0.acc: 95.4565, s0.loss_bbox: 0.0994, s1.loss_cls: 0.0603, s1.acc: 95.4102, s1.loss_bbox: 0.0889, s2.loss_cls: 0.0208, s2.acc: 97.2437, s2.loss_bbox: 0.0270, loss: 0.4405
# 2021-07-17 08:13:08,950 - mmdet - INFO - Epoch [3][200/859]	lr: 2.293e-03, eta: 4:06:15, time: 1.812, data_time: 0.011, memory: 8207, loss_rpn_cls: 0.0157, loss_rpn_bbox: 0.0096, s0.loss_cls: 0.1316, s0.acc: 94.9243, s0.loss_bbox: 0.1020, s1.loss_cls: 0.0645, s1.acc: 94.8706, s1.loss_bbox: 0.0900, s2.loss_cls: 0.0235, s2.acc: 96.7944, s2.loss_bbox: 0.0299, loss: 0.4668
# 2021-07-17 08:13:45,033 - mmdet - INFO - Epoch [3][220/859]	lr: 2.288e-03, eta: 4:05:44, time: 1.804, data_time: 0.012, memory: 8207, loss_rpn_cls: 0.0185, loss_rpn_bbox: 0.0093, s0.loss_cls: 0.1424, s0.acc: 94.6997, s0.loss_bbox: 0.1134, s1.loss_cls: 0.0696, s1.acc: 94.4214, s1.loss_bbox: 0.0965, s2.loss_cls: 0.0242, s2.acc: 96.9897, s2.loss_bbox: 0.0261, loss: 0.4999
# 2021-07-17 08:14:21,141 - mmdet - INFO - Epoch [3][240/859]	lr: 2.284e-03, eta: 4:05:12, time: 1.806, data_time: 0.011, memory: 8207, loss_rpn_cls: 0.0151, loss_rpn_bbox: 0.0080, s0.loss_cls: 0.1308, s0.acc: 95.0317, s0.loss_bbox: 0.1042, s1.loss_cls: 0.0607, s1.acc: 95.3149, s1.loss_bbox: 0.0831, s2.loss_cls: 0.0220, s2.acc: 97.1606, s2.loss_bbox: 0.0270, loss: 0.4510
# 2021-07-17 08:14:57,809 - mmdet - INFO - Epoch [3][260/859]	lr: 2.280e-03, eta: 4:04:43, time: 1.833, data_time: 0.013, memory: 8207, loss_rpn_cls: 0.0184, loss_rpn_bbox: 0.0090, s0.loss_cls: 0.1207, s0.acc: 95.2588, s0.loss_bbox: 0.1056, s1.loss_cls: 0.0655, s1.acc: 94.6289, s1.loss_bbox: 0.1032, s2.loss_cls: 0.0253, s2.acc: 96.3428, s2.loss_bbox: 0.0358, loss: 0.4835
# 2021-07-17 08:15:33,982 - mmdet - INFO - Epoch [3][280/859]	lr: 2.276e-03, eta: 4:04:11, time: 1.809, data_time: 0.011, memory: 8207, loss_rpn_cls: 0.0184, loss_rpn_bbox: 0.0078, s0.loss_cls: 0.1315, s0.acc: 95.0195, s0.loss_bbox: 0.1023, s1.loss_cls: 0.0684, s1.acc: 94.7485, s1.loss_bbox: 0.0997, s2.loss_cls: 0.0268, s2.acc: 95.9619, s2.loss_bbox: 0.0357, loss: 0.4907
# 2021-07-17 08:16:10,149 - mmdet - INFO - Epoch [3][300/859]	lr: 2.271e-03, eta: 4:03:40, time: 1.808, data_time: 0.011, memory: 8207, loss_rpn_cls: 0.0193, loss_rpn_bbox: 0.0096, s0.loss_cls: 0.1172, s0.acc: 95.4688, s0.loss_bbox: 0.1013, s1.loss_cls: 0.0633, s1.acc: 94.7754, s1.loss_bbox: 0.1009, s2.loss_cls: 0.0241, s2.acc: 96.5283, s2.loss_bbox: 0.0341, loss: 0.4697
# 2021-07-17 08:16:46,215 - mmdet - INFO - Epoch [3][320/859]	lr: 2.267e-03, eta: 4:03:08, time: 1.803, data_time: 0.012, memory: 8207, loss_rpn_cls: 0.0158, loss_rpn_bbox: 0.0085, s0.loss_cls: 0.1225, s0.acc: 95.4785, s0.loss_bbox: 0.1018, s1.loss_cls: 0.0613, s1.acc: 95.0830, s1.loss_bbox: 0.0949, s2.loss_cls: 0.0231, s2.acc: 96.6187, s2.loss_bbox: 0.0302, loss: 0.4582
# 2021-07-17 08:17:22,559 - mmdet - INFO - Epoch [3][340/859]	lr: 2.262e-03, eta: 4:02:37, time: 1.817, data_time: 0.012, memory: 8207, loss_rpn_cls: 0.0182, loss_rpn_bbox: 0.0075, s0.loss_cls: 0.1417, s0.acc: 94.8267, s0.loss_bbox: 0.1084, s1.loss_cls: 0.0667, s1.acc: 95.0171, s1.loss_bbox: 0.0955, s2.loss_cls: 0.0239, s2.acc: 96.7749, s2.loss_bbox: 0.0295, loss: 0.4914
# 2021-07-17 08:17:58,602 - mmdet - INFO - Epoch [3][360/859]	lr: 2.258e-03, eta: 4:02:04, time: 1.802, data_time: 0.011, memory: 8207, loss_rpn_cls: 0.0177, loss_rpn_bbox: 0.0088, s0.loss_cls: 0.1356, s0.acc: 95.0269, s0.loss_bbox: 0.0983, s1.loss_cls: 0.0634, s1.acc: 95.1562, s1.loss_bbox: 0.0888, s2.loss_cls: 0.0235, s2.acc: 96.6040, s2.loss_bbox: 0.0307, loss: 0.4668
# 2021-07-17 08:18:34,724 - mmdet - INFO - Epoch [3][380/859]	lr: 2.253e-03, eta: 4:01:32, time: 1.806, data_time: 0.012, memory: 8207, loss_rpn_cls: 0.0171, loss_rpn_bbox: 0.0100, s0.loss_cls: 0.1261, s0.acc: 95.0903, s0.loss_bbox: 0.0979, s1.loss_cls: 0.0629, s1.acc: 94.8828, s1.loss_bbox: 0.0938, s2.loss_cls: 0.0243, s2.acc: 96.4600, s2.loss_bbox: 0.0321, loss: 0.4643
# 2021-07-17 08:19:11,104 - mmdet - INFO - Epoch [3][400/859]	lr: 2.249e-03, eta: 4:01:01, time: 1.819, data_time: 0.012, memory: 8207, loss_rpn_cls: 0.0137, loss_rpn_bbox: 0.0074, s0.loss_cls: 0.1171, s0.acc: 95.6641, s0.loss_bbox: 0.0954, s1.loss_cls: 0.0608, s1.acc: 95.2588, s1.loss_bbox: 0.0885, s2.loss_cls: 0.0236, s2.acc: 96.6284, s2.loss_bbox: 0.0305, loss: 0.4371
# 2021-07-17 08:19:47,490 - mmdet - INFO - Epoch [3][420/859]	lr: 2.244e-03, eta: 4:00:30, time: 1.819, data_time: 0.012, memory: 8207, loss_rpn_cls: 0.0164, loss_rpn_bbox: 0.0078, s0.loss_cls: 0.1272, s0.acc: 95.2026, s0.loss_bbox: 0.1047, s1.loss_cls: 0.0655, s1.acc: 94.7607, s1.loss_bbox: 0.0976, s2.loss_cls: 0.0256, s2.acc: 96.1768, s2.loss_bbox: 0.0352, loss: 0.4801
# 2021-07-17 08:20:23,938 - mmdet - INFO - Epoch [3][440/859]	lr: 2.239e-03, eta: 3:59:59, time: 1.822, data_time: 0.012, memory: 8207, loss_rpn_cls: 0.0189, loss_rpn_bbox: 0.0081, s0.loss_cls: 0.1137, s0.acc: 95.5518, s0.loss_bbox: 0.0941, s1.loss_cls: 0.0599, s1.acc: 95.1880, s1.loss_bbox: 0.0961, s2.loss_cls: 0.0244, s2.acc: 96.1304, s2.loss_bbox: 0.0333, loss: 0.4485
# 2021-07-17 08:21:00,336 - mmdet - INFO - Epoch [3][460/859]	lr: 2.235e-03, eta: 3:59:28, time: 1.820, data_time: 0.012, memory: 8207, loss_rpn_cls: 0.0129, loss_rpn_bbox: 0.0072, s0.loss_cls: 0.1245, s0.acc: 95.1831, s0.loss_bbox: 0.1006, s1.loss_cls: 0.0634, s1.acc: 94.7852, s1.loss_bbox: 0.0932, s2.loss_cls: 0.0247, s2.acc: 96.4160, s2.loss_bbox: 0.0331, loss: 0.4597
# 2021-07-17 08:21:36,366 - mmdet - INFO - Epoch [3][480/859]	lr: 2.230e-03, eta: 3:58:55, time: 1.801, data_time: 0.011, memory: 8207, loss_rpn_cls: 0.0137, loss_rpn_bbox: 0.0076, s0.loss_cls: 0.1343, s0.acc: 94.9829, s0.loss_bbox: 0.1092, s1.loss_cls: 0.0663, s1.acc: 95.0977, s1.loss_bbox: 0.0928, s2.loss_cls: 0.0238, s2.acc: 96.8384, s2.loss_bbox: 0.0297, loss: 0.4775
# 2021-07-17 08:22:12,594 - mmdet - INFO - Epoch [3][500/859]	lr: 2.225e-03, eta: 3:58:23, time: 1.811, data_time: 0.012, memory: 8207, loss_rpn_cls: 0.0189, loss_rpn_bbox: 0.0078, s0.loss_cls: 0.1291, s0.acc: 95.2515, s0.loss_bbox: 0.1019, s1.loss_cls: 0.0682, s1.acc: 94.6826, s1.loss_bbox: 0.0986, s2.loss_cls: 0.0246, s2.acc: 96.7334, s2.loss_bbox: 0.0311, loss: 0.4802
# ...
# 2021-07-17 12:32:38,549 - mmdet - INFO - Epoch [12][300/859]	lr: 1.826e-05, eta: 0:16:29, time: 1.794, data_time: 0.011, memory: 8207, loss_rpn_cls: 0.0080, loss_rpn_bbox: 0.0059, s0.loss_cls: 0.0901, s0.acc: 96.2598, s0.loss_bbox: 0.0838, s1.loss_cls: 0.0585, s1.acc: 95.1245, s1.loss_bbox: 0.1175, s2.loss_cls: 0.0297, s2.acc: 94.9487, s2.loss_bbox: 0.0587, loss: 0.4522
# 2021-07-17 12:33:14,763 - mmdet - INFO - Epoch [12][320/859]	lr: 1.699e-05, eta: 0:15:54, time: 1.811, data_time: 0.014, memory: 8207, loss_rpn_cls: 0.0101, loss_rpn_bbox: 0.0072, s0.loss_cls: 0.0967, s0.acc: 96.0010, s0.loss_bbox: 0.0815, s1.loss_cls: 0.0608, s1.acc: 94.7314, s1.loss_bbox: 0.1046, s2.loss_cls: 0.0292, s2.acc: 95.0464, s2.loss_bbox: 0.0513, loss: 0.4414
# 2021-07-17 12:33:50,897 - mmdet - INFO - Epoch [12][340/859]	lr: 1.576e-05, eta: 0:15:19, time: 1.807, data_time: 0.012, memory: 8207, loss_rpn_cls: 0.0077, loss_rpn_bbox: 0.0064, s0.loss_cls: 0.0998, s0.acc: 95.6665, s0.loss_bbox: 0.0897, s1.loss_cls: 0.0647, s1.acc: 94.3140, s1.loss_bbox: 0.1182, s2.loss_cls: 0.0314, s2.acc: 94.3262, s2.loss_bbox: 0.0519, loss: 0.4698
# 2021-07-17 12:34:26,996 - mmdet - INFO - Epoch [12][360/859]	lr: 1.458e-05, eta: 0:14:43, time: 1.805, data_time: 0.012, memory: 8207, loss_rpn_cls: 0.0083, loss_rpn_bbox: 0.0058, s0.loss_cls: 0.0944, s0.acc: 95.9619, s0.loss_bbox: 0.0870, s1.loss_cls: 0.0602, s1.acc: 94.6655, s1.loss_bbox: 0.1188, s2.loss_cls: 0.0311, s2.acc: 94.6777, s2.loss_bbox: 0.0558, loss: 0.4614
# 2021-07-17 12:35:03,119 - mmdet - INFO - Epoch [12][380/859]	lr: 1.345e-05, eta: 0:14:08, time: 1.806, data_time: 0.012, memory: 8207, loss_rpn_cls: 0.0053, loss_rpn_bbox: 0.0057, s0.loss_cls: 0.0932, s0.acc: 96.0278, s0.loss_bbox: 0.0878, s1.loss_cls: 0.0604, s1.acc: 94.6777, s1.loss_bbox: 0.1124, s2.loss_cls: 0.0311, s2.acc: 94.5654, s2.loss_bbox: 0.0543, loss: 0.4501
# 2021-07-17 12:35:39,538 - mmdet - INFO - Epoch [12][400/859]	lr: 1.236e-05, eta: 0:13:32, time: 1.821, data_time: 0.012, memory: 8207, loss_rpn_cls: 0.0078, loss_rpn_bbox: 0.0063, s0.loss_cls: 0.0958, s0.acc: 96.0034, s0.loss_bbox: 0.0824, s1.loss_cls: 0.0601, s1.acc: 94.9805, s1.loss_bbox: 0.1094, s2.loss_cls: 0.0296, s2.acc: 94.6802, s2.loss_bbox: 0.0505, loss: 0.4419
# 2021-07-17 12:36:15,517 - mmdet - INFO - Epoch [12][420/859]	lr: 1.132e-05, eta: 0:12:57, time: 1.799, data_time: 0.011, memory: 8207, loss_rpn_cls: 0.
data_time: 0.011, memory: 8207, loss_rpn_cls: 0.0102, loss_rpn_bbox: 0.0052, s0.loss_cls: 0.0951, s0.acc: 95.9253, s0.loss_bbox: 0.0817, s1.loss_cls: 0.0626, s1.acc: 94.4946, s1.loss_bbox: 0.1181, s2.loss_cls: 0.0324, s2.acc: 94.0479, s2.loss_bbox: 0.0565, loss: 0.4619
# 2021-07-17 12:45:54,030 - mmdet - INFO - Epoch [12][740/859]	lr: 9.358e-07, eta: 0:03:30, time: 1.803, data_time: 0.013, memory: 8207, loss_rpn_cls: 0.0066, loss_rpn_bbox: 0.0071, s0.loss_cls: 0.0900, s0.acc: 96.1841, s0.loss_bbox: 0.0838, s1.loss_cls: 0.0586, s1.acc: 94.8853, s1.loss_bbox: 0.1150, s2.loss_cls: 0.0294, s2.acc: 95.0488, s2.loss_bbox: 0.0548, loss: 0.4453
# 2021-07-17 12:46:30,449 - mmdet - INFO - Epoch [12][760/859]	lr: 6.805e-07, eta: 0:02:55, time: 1.821, data_time: 0.012, memory: 8207, loss_rpn_cls: 0.0087, loss_rpn_bbox: 0.0075, s0.loss_cls: 0.0933, s0.acc: 96.0767, s0.loss_bbox: 0.0820, s1.loss_cls: 0.0590, s1.acc: 94.7363, s1.loss_bbox: 0.1083, s2.loss_cls: 0.0308, s2.acc: 94.4360, s2.loss_bbox: 0.0564, loss: 0.4462
# 2021-07-17 12:47:06,476 - mmdet - INFO - Epoch [12][780/859]	lr: 4.715e-07, eta: 0:02:20, time: 1.801, data_time: 0.011, memory: 8207, loss_rpn_cls: 0.0090, loss_rpn_bbox: 0.0064, s0.loss_cls: 0.1038, s0.acc: 95.6714, s0.loss_bbox: 0.0921, s1.loss_cls: 0.0634, s1.acc: 94.4995, s1.loss_bbox: 0.1176, s2.loss_cls: 0.0314, s2.acc: 94.6924, s2.loss_bbox: 0.0541, loss: 0.4778
# 2021-07-17 12:47:42,594 - mmdet - INFO - Epoch [12][800/859]	lr: 3.090e-07, eta: 0:01:44, time: 1.806, data_time: 0.012, memory: 8207, loss_rpn_cls: 0.0063, loss_rpn_bbox: 0.0074, s0.loss_cls: 0.0915, s0.acc: 96.1475, s0.loss_bbox: 0.0825, s1.loss_cls: 0.0604, s1.acc: 94.8242, s1.loss_bbox: 0.1089, s2.loss_cls: 0.0305, s2.acc: 94.7656, s2.loss_bbox: 0.0524, loss: 0.4399
# 2021-07-17 12:48:18,925 - mmdet - INFO - Epoch [12][820/859]	lr: 1.929e-07, eta: 0:01:09, time: 1.817, data_time: 0.014, memory: 8207, loss_rpn_cls: 0.0082, loss_rpn_bbox: 0.0057, s0.loss_cls: 0.0896, s0.acc: 96.2524, s0.loss_bbox: 0.0820, s1.loss_cls: 0.0598, s1.acc: 94.7852, s1.loss_bbox: 0.1158, s2.loss_cls: 0.0317, s2.acc: 94.2480, s2.loss_bbox: 0.0620, loss: 0.4548
# 2021-07-17 12:48:55,055 - mmdet - INFO - Epoch [12][840/859]	lr: 1.232e-07, eta: 0:00:33, time: 1.806, data_time: 0.012, memory: 8207, loss_rpn_cls: 0.0093, loss_rpn_bbox: 0.0081, s0.loss_cls: 0.1141, s0.acc: 95.4150, s0.loss_bbox: 0.0936, s1.loss_cls: 0.0689, s1.acc: 94.1309, s1.loss_bbox: 0.1211, s2.loss_cls: 0.0325, s2.acc: 94.3408, s2.loss_bbox: 0.0536, loss: 0.5011
# 2021-07-17 12:49:29,381 - mmdet - INFO - Saving checkpoint at 12 epochs
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 858/858, 5.7 task/s, elapsed: 151s, ETA:     0s
# 2021-07-17 12:52:02,853 - mmdet - INFO - Evaluating bbox...
# Loading and preparing results...
# DONE (t=0.02s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# 2021-07-17 12:52:03,410 - mmdet - INFO - Epoch(val) [12][858]	bbox_mAP: 0.5300, bbox_mAP_50: -1.0000, bbox_mAP_75: -1.0000, bbox_mAP_s: 0.0100, bbox_mAP_m: 0.1900, bbox_mAP_l: 0.6110, bbox_mAP_copypaste: 0.530 -1.000 -1.000 0.010 0.190 0.611
# DONE (t=0.40s).
# Accumulating evaluation results...
# DONE (t=0.09s).
#  Average Precision  (AP) @[ IoU=0.50:0.50 | area=   all | maxDets=100 ] = 0.530
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=1000 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=1000 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.50 | area= small | maxDets=1000 ] = 0.010
#  Average Precision  (AP) @[ IoU=0.50:0.50 | area=medium | maxDets=1000 ] = 0.190
#  Average Precision  (AP) @[ IoU=0.50:0.50 | area= large | maxDets=1000 ] = 0.611
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area=   all | maxDets=100 ] = 0.791
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area=   all | maxDets=300 ] = 0.791
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area=   all | maxDets=1000 ] = 0.791
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area= small | maxDets=1000 ] = 0.200
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area=medium | maxDets=1000 ] = 0.505
#  Average Recall     (AR) @[ IoU=0.50:0.50 | area= large | maxDets=1000 ] = 0.867
# <br/>Waiting for W&B process to finish, PID 238<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/kaggle/working/wandb/run-20210717_071035-l9ojrenr/logs/debug.log</code>
# Find internal logs for this run at: <code>/kaggle/working/wandb/run-20210717_071035-l9ojrenr/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train/loss_rpn_cls</td><td>0.00926</td></tr><tr><td>train/loss_rpn_bbox</td><td>0.00806</td></tr><tr><td>train/s0.loss_cls</td><td>0.11406</td></tr><tr><td>train/s0.acc</td><td>95.41504</td></tr><tr><td>train/s0.loss_bbox</td><td>0.09355</td></tr><tr><td>train/s1.loss_cls</td><td>0.06892</td></tr><tr><td>train/s1.acc</td><td>94.13086</td></tr><tr><td>train/s1.loss_bbox</td><td>0.12114</td></tr><tr><td>train/s2.loss_cls</td><td>0.03247</td></tr><tr><td>train/s2.acc</td><td>94.34082</td></tr><tr><td>train/s2.loss_bbox</td><td>0.05365</td></tr><tr><td>train/loss</td><td>0.50111</td></tr><tr><td>learning_rate</td><td>0.0</td></tr><tr><td>momentum</td><td>0.9</td></tr><tr><td>_runtime</td><td>20488</td></tr><tr><td>_timestamp</td><td>1626526323</td></tr><tr><td>_step</td><td>10309</td></tr><tr><td>val/bbox_mAP</td><td>0.53</td></tr><tr><td>val/bbox_mAP_50</td><td>-1.0</td></tr><tr><td>val/bbox_mAP_75</td><td>-1.0</td></tr><tr><td>val/bbox_mAP_s</td><td>0.01</td></tr><tr><td>val/bbox_mAP_m</td><td>0.19</td></tr><tr><td>val/bbox_mAP_l</td><td>0.611</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>train/loss_rpn_cls</td><td>█▃▃▂▂▂▃▂▂▂▂▂▁▂▂▂▁▁▁▂▂▁▂▁▁▂▁▁▁▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss_rpn_bbox</td><td>█▅▆▆▆▆▄▄▃▄▃▃▁▄▃▃▃▂▅▄▄▂▅▂▂▂▃▂▂▄▁▂▁▁▂▂▁▂▂▄</td></tr><tr><td>train/s0.loss_cls</td><td>▅▆▇▆▆█▇▇▅▇▆▇▆▇▅▅▇▅▅█▆▅▄▄▄▅▃▄▃▆▄▄▃▂▃▂▁▃▂▅</td></tr><tr><td>train/s0.acc</td><td>█▇▅▅▄▃▄▂▅▃▃▃▃▂▄▄▁▅▄▁▃▄▆▅▄▄▆▆▆▃▄▄▅▇▆▆█▅▇▄</td></tr><tr><td>train/s0.loss_bbox</td><td>▆▃▄▅▅▅▅▆▄▆▃▆▅▆▄▄█▃▄█▄▄▃▃▅▄▂▂▂▄▃▃▃▁▃▃▁▃▁▃</td></tr><tr><td>train/s1.loss_cls</td><td>▁▄▅▅▆▆▆▇▆▇▇▇▇█▇▇█▆▇█▇▆▆▆▇▇▇▆▆█▇▇▇▆▆▆▅▇▆█</td></tr><tr><td>train/s1.acc</td><td>█▅▄▃▃▃▃▂▃▂▂▂▂▁▂▂▁▂▂▁▂▂▃▂▁▁▂▂▂▁▂▁▁▂▂▁▃▁▂▁</td></tr><tr><td>train/s1.loss_bbox</td><td>▁▄▄▅▆▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▆▇▇▇▇▇▇▇▇██▇▇███▇█</td></tr><tr><td>train/s2.loss_cls</td><td>▁▃▄▄▅▄▄▅▅▅▅▆▅▆▆▆▆▆▇▆▆▆▆▆▇▇▇▇▇▇▇█▇▇▇█▇█▇█</td></tr><tr><td>train/s2.acc</td><td>█▆▆▅▅▅▅▄▄▄▄▄▄▄▃▃▄▃▃▄▃▃▃▃▂▃▂▂▁▂▂▁▂▂▂▁▁▂▂▁</td></tr><tr><td>train/s2.loss_bbox</td><td>▁▂▃▄▄▃▄▄▄▄▄▄▅▅▅▅▅▅▅▅▅▅▅▆▆▆▆▆▇▆▇▇▆▇▆▇█▇▆▇</td></tr><tr><td>train/loss</td><td>▁▂▃▄▅▅▅▆▄▅▄▆▅▇▆▆▇▄▅█▆▅▄▅▆▆▅▄▅▇▆▆▅▃▅▅▄▆▄▇</td></tr><tr><td>learning_rate</td><td>▃▆█████▇▇▇▇▇▇▆▆▆▆▅▅▅▄▄▄▄▃▃▃▃▂▂▂▂▂▁▁▁▁▁▁▁</td></tr><tr><td>momentum</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>val/bbox_mAP</td><td>▁▅▅▅▇▇█▇▇█▇▇</td></tr><tr><td>val/bbox_mAP_50</td><td>▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val/bbox_mAP_75</td><td>▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val/bbox_mAP_s</td><td>▁▁█▁▁▁▁▃▁▂▂▂</td></tr><tr><td>val/bbox_mAP_m</td><td>▂▃▆█▄▃▅▃▁▄▂▃</td></tr><tr><td>val/bbox_mAP_l</td><td>▁▅▅▅▆▇██▇█▇▇</td></tr></table><br/>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">exp-cascade_rcnn_x101_32x4d_fpn_1x-fold0-job4</strong>: <a href="https://wandb.ai/sreevishnu-damodaran/siim-covid19-1/runs/l9ojrenr" target="_blank">https://wandb.ai/sreevishnu-damodaran/siim-covid19-1/runs/l9ojrenr</a><br/>

# %% [markdown]
# <span style="font-size: 1.3em; font-weight: 300;">📌 Please visit the Weights and Biases Dashboard (<a href="https://wandb.ai/sreevishnu-damodaran/siim-covid19-1">https://wandb.ai/sreevishnu-damodaran/siim-covid19-1</a>) to see the current training progress and the results of some experiments which I ran previously.</span>

# %% [markdown]
# <span style="color: #E45D00; font-family: Segoe UI; font-size: 1.9em; font-weight: 300;">Save Model Files in WnB as Artifacts</span>
#
# <br>
#
# ![](https://i.ibb.co/vhdzH4j/gif3.gif)

# %%
# Get the best epoch number
import json
from collections import defaultdict

log_file = f'{job_folder}/None.log.json'

# Source: mmdetection/tools/analysis_tools/analyze_logs.py 
def load_json_logs(json_logs):
    # load and convert json_logs to log_dict, key is epoch, value is a sub dict
    # keys of sub dict is different metrics, e.g. memory, bbox_mAP
    # value of sub dict is a list of corresponding values of all iterations
    log_dicts = [dict() for _ in json_logs]
    for json_log, log_dict in zip(json_logs, log_dicts):
        with open(json_log, 'r') as log_file:
            for line in log_file:
                log = json.loads(line.strip())
                # skip lines without `epoch` field
                if 'epoch' not in log:
                    continue
                epoch = log.pop('epoch')
                if epoch not in log_dict:
                    log_dict[epoch] = defaultdict(list)
                for k, v in log.items():
                    log_dict[epoch][k].append(v)
    return log_dicts

log_dict = load_json_logs([log_file])
# [(print(inner['bbox_mAP']) for inner in item) for item in log_dict]
# [print(item) for item in log_dict[0]]
best_epoch = np.argmax([item['bbox_mAP'][0] for item in log_dict[0].values()])+1
best_epoch
# Out:
# 10

# %%
model_files = [f'{job_folder}/epoch_{best_epoch}.pth',
               cfg_path
              ]

# Create a new wnb run for saving models as artifacts
run = wandb.init(project=wnb_project_name,
                 name=f'models_files_{model_name}_fold{fold}_job{job}',
                 entity=wnb_username,
                 group='Artifact',
                 job_type='model-files')

artifact = wandb.Artifact(f'models_files_{model_name}_fold{fold}_job{job}', type='model')

for model_file in model_files:
    artifact.add_file(model_file)

run.log_artifact(artifact)
run.finish()
# Out:
#                 Tracking run with wandb version 0.11.0<br/>
#                 Syncing run <strong style="color:#cdcd00">models_files_cascade_rcnn_x101_32x4d_fpn_1x_fold0_job4</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/sreevishnu-damodaran/siim-covid19-1" target="_blank">https://wandb.ai/sreevishnu-damodaran/siim-covid19-1</a><br/>
#                 Run page: <a href="https://wandb.ai/sreevishnu-damodaran/siim-covid19-1/runs/1rvu1nxb" target="_blank">https://wandb.ai/sreevishnu-damodaran/siim-covid19-1/runs/1rvu1nxb</a><br/>
#                 Run data is saved locally in <code>/kaggle/working/wandb/run-20210717_125233-1rvu1nxb</code><br/><br/>
# <br/>Waiting for W&B process to finish, PID 13732<br/>Program ended successfully.
# VBox(children=(Label(value=' 669.68MB of 669.68MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=…
# Find user logs for this run at: <code>/kaggle/working/wandb/run-20210717_125233-1rvu1nxb/logs/debug.log</code>
# Find internal logs for this run at: <code>/kaggle/working/wandb/run-20210717_125233-1rvu1nxb/logs/debug-internal.log</code>
# Synced 4 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">models_files_cascade_rcnn_x101_32x4d_fpn_1x_fold0_job4</strong>: <a href="https://wandb.ai/sreevishnu-damodaran/siim-covid19-1/runs/1rvu1nxb" target="_blank">https://wandb.ai/sreevishnu-damodaran/siim-covid19-1/runs/1rvu1nxb</a><br/>

# %% [markdown]
# <span style="color: #E45D00; font-family: Segoe UI; font-size: 1.9em; font-weight: 300;">📰 Inference and Visualize Output</span>

# %%
import mmcv
from mmdet.models import build_detector
from mmcv.runner import load_checkpoint
from mmcv.parallel import MMDataParallel
from mmdet.datasets import build_dataloader, build_dataset
from mmdet.apis import single_gpu_test
from mmdet.apis import init_detector, inference_detector, show_result_pyplot

import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path
import cv2
import json

# %%
with open("../input/siim-covid19-coco-512x512-groupkfold/val_annotations_fold0.json") as f:
    val_ann = json.load(f)
imagepaths = [item['file_name'] for item in val_ann['images'][:9]]

df_annotations = pd.read_csv('../input/siim-covid19-512-images-and-metadata/df_train_processed_meta.csv')

# %%
def draw_bbox(image,
              box,
              label,
              color,
              label_size = 0.5,
              alpha_box = 0.3,
              alpha_label = 0.6):
    
    overlay_bbox = image.copy()
    overlay_label = image.copy()
    output = image.copy()

    text_width, text_height = cv2.getTextSize(label.upper(),
                                              cv2.FONT_HERSHEY_SIMPLEX, label_size, 1)[0]
    cv2.rectangle(overlay_bbox, (box[0], box[1]), (box[2], box[3]),
                  color, -1)
    cv2.addWeighted(overlay_bbox, alpha_box, output, 1-alpha_box, 0, output)
    
    cv2.rectangle(overlay_label, (box[0], box[1]-7-text_height),
                  (box[0]+text_width+2, box[1]), (0, 0, 0), -1)
    cv2.addWeighted(overlay_label, alpha_label, output, 1-alpha_label, 0, output)
    output = cv2.rectangle(output, (box[0], box[1]), (box[2], box[3]),
                           color, 2)
    cv2.putText(output, label.upper(), (box[0], box[1]-5),
            cv2.FONT_HERSHEY_SIMPLEX, label_size, (255, 255, 255), 1, cv2.LINE_AA)
    return output

# %%
checkpoint = f'{job_folder}/epoch_{best_epoch}.pth'

print("Loading weights from:", checkpoint)
cfg = Config.fromfile(cfg_path)
model = init_detector(cfg, checkpoint, device='cuda:0')
# Out:
# Loading weights from: /kaggle/working/job4_cascade_rcnn_x101_32x4d_fpn_1x_fold0/epoch_10.pth
# Use load_from_local loader
# ./mmdetection/mmdet/apis/inference.py:47: UserWarning: Class names are not saved in the checkpoint's meta data, use COCO classes by default.
#   warnings.warn('Class names are not saved in the checkpoint\'s '

# %%
new_size = (512, 512)
imgs_path = "/kaggle/input/siim-covid19-512-images-and-metadata/train"
threshold = 0.45

fig, axes = plt.subplots(3,3, figsize=(19,21))
fig.subplots_adjust(hspace=0.2, wspace=0.2)
axes = axes.ravel()

results_list = []

for idx, img_id in enumerate(imagepaths):
    img_path = os.path.join(imgs_path, img_id)
    img = cv2.imread(img_path)
    result = inference_detector(model, img_path)
    results_filtered = result[0][result[0][:, 4]>threshold]
    bboxes = results_filtered[:, :4]
    scores = results_filtered[:, 4] 
    results_list.append(result[0])
    
    for box in bboxes:
        img = draw_bbox(img, list(np.int_(box)), "Covid_Abnormality",
                        (255, 243, 0))

    axes[idx].imshow(img, cmap='gray')
    axes[idx].set_title(img_id, size=18, pad=30)
    axes[idx].set_xticklabels([])
    axes[idx].set_yticklabels([])
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ./mmdetection/mmdet/datasets/utils.py:68: UserWarning: "ImageToTensor" pipeline is replaced by "DefaultFormatBundle" for batch inference. It is recommended to manually replace it in the test data pipeline in your config file.
#   'data pipeline in your config file.', UserWarning)
# ./mmdetection/mmdet/core/anchor/anchor_generator.py:323: UserWarning: ``grid_anchors`` would be deprecated soon. Please use ``grid_priors``
#   warnings.warn('``grid_anchors`` would be deprecated soon. '
# ./mmdetection/mmdet/core/anchor/anchor_generator.py:360: UserWarning: ``single_level_grid_anchors`` would be deprecated soon. Please use ``single_level_grid_priors``
#   '``single_level_grid_anchors`` would be deprecated soon. '

# %% [markdown]
# <span style="color: #E45D00; font-family: Segoe UI; font-size: 1.9em; font-weight: 300;">Interactively Visualize & Analyze Output in Dashboard</span>

# %%
run = wandb.init(project=wnb_project_name,
                 name=f'images-{model_name}-fold{fold}-job{job}',
                 job_type='images')

class_id_to_label = {
    1: "pred_covid_abnormality",
    2: "GT_covid_abnormality"
}

wnb_images = []

for img_id, result in zip(imagepaths, results_list):
    
    bboxes = result[:, :4]
    scores = result[:, 4]
    ann_dict = {"predictions":{
                        "box_data":[],
                        "class_labels": class_id_to_label
                        },
                "ground_truth":{
                        "box_data":[],
                        "class_labels": class_id_to_label
                        }
                    }

    for box, score in zip(bboxes, scores):
        single_data = {
            # one box expressed in the default relative/fractional domain
            "position": {
                "minX": round(float(box[0])/512, 3),
                "maxX": round(float(box[2])/512, 3),
                "minY": round(float(box[1])/512, 3),
                "maxY": round(float(box[3])/512, 3),
            },
            "class_id" : 1,
            "box_caption": class_id_to_label[1],
            "scores" : {
                "confidence": float(score),
            }
        }
        ann_dict["predictions"]["box_data"].append(single_data)

    image_annotations = df_annotations[df_annotations.id==img_id.strip('.png')]

    for idxx, row in image_annotations[['xmin', 'ymin', 'xmax', 'ymax']].iterrows():
        single_data = {
            # one box expressed in the default relative/fractional domain
            "position": {
                "minX": round(float(row[0])/512, 3),
                "maxX": round(float(row[2])/512, 3),
                "minY": round(float(row[1])/512, 3),
                "maxY": round(float(row[3])/512, 3),
            },
            "class_id" : 2,
            "box_caption": class_id_to_label[2],
            "scores" : {
                "confidence": 1.0,
            }
        }
        ann_dict["ground_truth"]["box_data"].append(single_data)

    image = cv2.imread(os.path.join(imgs_path, img_id))
    wnb_images.append(wandb.Image(image, boxes=ann_dict))
    
wandb.log({f'images-{model_name}-fold{fold}-job{job}': wnb_images})

run.finish()
run
# Out:
#                 Tracking run with wandb version 0.11.0<br/>
#                 Syncing run <strong style="color:#cdcd00">images-cascade_rcnn_x101_32x4d_fpn_1x-fold0-job4</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/sreevishnu-damodaran/siim-covid19-1" target="_blank">https://wandb.ai/sreevishnu-damodaran/siim-covid19-1</a><br/>
#                 Run page: <a href="https://wandb.ai/sreevishnu-damodaran/siim-covid19-1/runs/2j29lumv" target="_blank">https://wandb.ai/sreevishnu-damodaran/siim-covid19-1/runs/2j29lumv</a><br/>
#                 Run data is saved locally in <code>/kaggle/working/wandb/run-20210717_125351-2j29lumv</code><br/><br/>
# /opt/conda/lib/python3.7/site-packages/wandb/sdk/data_types.py:1243: ResourceWarning: unclosed file <_io.BufferedWriter name='/tmp/tmp20vehlcewandb-media/r4g1qv5j.boxes2D.json'>
#   self._val, codecs.open(tmp_path, "w", encoding="utf-8")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /opt/conda/lib/python3.7/site-packages/wandb/sdk/data_types.py:1243: ResourceWarning: unclosed file <_io.BufferedWriter name='/tmp/tmp20vehlcewandb-media/2oqso6tt.boxes2D.json'>
#   self._val, codecs.open(tmp_path, "w", encoding="utf-8")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /opt/conda/lib/python3.7/site-packages/wandb/sdk/data_types.py:1243: ResourceWarning: unclosed file <_io.BufferedWriter name='/tmp/tmp20vehlcewandb-media/lacr88mt.boxes2D.json'>
#   self._val, codecs.open(tmp_path, "w", encoding="utf-8")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /opt/conda/lib/python3.7/site-packages/wandb/sdk/data_types.py:1243: ResourceWarning: unclosed file <_io.BufferedWriter name='/tmp/tmp20vehlcewandb-media/2dzgl0ns.boxes2D.json'>
#   self._val, codecs.open(tmp_path, "w", encoding="utf-8")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /opt/conda/lib/python3.7/site-packages/wandb/sdk/data_types.py:1243: ResourceWarning: unclosed file <_io.BufferedWriter name='/tmp/tmp20vehlcewandb-media/nisy4hws.boxes2D.json'>
#   self._val, codecs.open(tmp_path, "w", encoding="utf-8")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /opt/conda/lib/python3.7/site-packages/wandb/sdk/data_types.py:1243: ResourceWarning: unclosed file <_io.BufferedWriter name='/tmp/tmp20vehlcewandb-media/3cv2k7gk.boxes2D.json'>
#   self._val, codecs.open(tmp_path, "w", encoding="utf-8")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /opt/conda/lib/python3.7/site-packages/wandb/sdk/data_types.py:1243: ResourceWarning: unclosed file <_io.BufferedWriter name='/tmp/tmp20vehlcewandb-media/1joekxso.boxes2D.json'>
#   self._val, codecs.open(tmp_path, "w", encoding="utf-8")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /opt/conda/lib/python3.7/site-packages/wandb/sdk/data_types.py:1243: ResourceWarning: unclosed file <_io.BufferedWriter name='/tmp/tmp20vehlcewandb-media/30bvg3xr.boxes2D.json'>
#   self._val, codecs.open(tmp_path, "w", encoding="utf-8")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /opt/conda/lib/python3.7/site-packages/wandb/sdk/data_types.py:1243: ResourceWarning: unclosed file <_io.BufferedWriter name='/tmp/tmp20vehlcewandb-media/ky6phpuz.boxes2D.json'>
#   self._val, codecs.open(tmp_path, "w", encoding="utf-8")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /opt/conda/lib/python3.7/site-packages/wandb/sdk/data_types.py:1243: ResourceWarning: unclosed file <_io.BufferedWriter name='/tmp/tmp20vehlcewandb-media/17vjqqsc.boxes2D.json'>
#   self._val, codecs.open(tmp_path, "w", encoding="utf-8")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /opt/conda/lib/python3.7/site-packages/wandb/sdk/data_types.py:1243: ResourceWarning: unclosed file <_io.BufferedWriter name='/tmp/tmp20vehlcewandb-media/1apkr1wp.boxes2D.json'>
#   self._val, codecs.open(tmp_path, "w", encoding="utf-8")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /opt/conda/lib/python3.7/site-packages/wandb/sdk/data_types.py:1243: ResourceWarning: unclosed file <_io.BufferedWriter name='/tmp/tmp20vehlcewandb-media/eki3s8r5.boxes2D.json'>
#   self._val, codecs.open(tmp_path, "w", encoding="utf-8")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /opt/conda/lib/python3.7/site-packages/wandb/sdk/data_types.py:1243: ResourceWarning: unclosed file <_io.BufferedWriter name='/tmp/tmp20vehlcewandb-media/bt0p0xv3.boxes2D.json'>
#   self._val, codecs.open(tmp_path, "w", encoding="utf-8")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /opt/conda/lib/python3.7/site-packages/wandb/sdk/data_types.py:1243: ResourceWarning: unclosed file <_io.BufferedWriter name='/tmp/tmp20vehlcewandb-media/d5cgenvv.boxes2D.json'>
#   self._val, codecs.open(tmp_path, "w", encoding="utf-8")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /opt/conda/lib/python3.7/site-packages/wandb/sdk/data_types.py:1243: ResourceWarning: unclosed file <_io.BufferedWriter name='/tmp/tmp20vehlcewandb-media/1o0mia5q.boxes2D.json'>
#   self._val, codecs.open(tmp_path, "w", encoding="utf-8")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /opt/conda/lib/python3.7/site-packages/wandb/sdk/data_types.py:1243: ResourceWarning: unclosed file <_io.BufferedWriter name='/tmp/tmp20vehlcewandb-media/nvzm7zqy.boxes2D.json'>
#   self._val, codecs.open(tmp_path, "w", encoding="utf-8")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /opt/conda/lib/python3.7/site-packages/wandb/sdk/data_types.py:1243: ResourceWarning: unclosed file <_io.BufferedWriter name='/tmp/tmp20vehlcewandb-media/2ro69t1h.boxes2D.json'>
#   self._val, codecs.open(tmp_path, "w", encoding="utf-8")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /opt/conda/lib/python3.7/site-packages/wandb/sdk/data_types.py:1243: ResourceWarning: unclosed file <_io.BufferedWriter name='/tmp/tmp20vehlcewandb-media/2ifbijxr.boxes2D.json'>
#   self._val, codecs.open(tmp_path, "w", encoding="utf-8")
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# <br/>Waiting for W&B process to finish, PID 13821<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.39MB of 1.41MB uploaded (0.00MB deduped)\r'), FloatProgress(value=0.27730419747…
# Find user logs for this run at: <code>/kaggle/working/wandb/run-20210717_125351-2j29lumv/logs/debug.log</code>
# Find internal logs for this run at: <code>/kaggle/working/wandb/run-20210717_125351-2j29lumv/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>7</td></tr><tr><td>_timestamp</td><td>1626526438</td></tr><tr><td>_step</td><td>0</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>_runtime</td><td>▁</td></tr><tr><td>_timestamp</td><td>▁</td></tr><tr><td>_step</td><td>▁</td></tr></table><br/>
# Synced 5 W&B file(s), 27 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">images-cascade_rcnn_x101_32x4d_fpn_1x-fold0-job4</strong>: <a href="https://wandb.ai/sreevishnu-damodaran/siim-covid19-1/runs/2j29lumv" target="_blank">https://wandb.ai/sreevishnu-damodaran/siim-covid19-1/runs/2j29lumv</a><br/>
# <h1>Run(2j29lumv)</h1><iframe src="https://wandb.ai/sreevishnu-damodaran/siim-covid19-1/runs/2j29lumv" style="border:none;width:100%;height:400px"></iframe>

# %% [markdown]
# <span style="font-size: 1.3em; font-weight: 300;">🚩 Click on the ⚙️ icon to change the bbox threshold</span>
#
# <span style="font-size: 1.3em; font-weight: 300;">🚩 Visit the <a href="https://wandb.ai/sreevishnu-damodaran/siim-covid19-1"> training job run page</a> and the <a href="https://wandb.ai/sreevishnu-damodaran/siim-covid19-1/runs/1xt003e4"> images run page</a> to see the interactive visualizations of training metrics and images in detail</span>
#
# ![](https://i.ibb.co/c3DFpmt/gif2.gif)

# %%
# !rm -rf mmdetection/

# %% [markdown]
# <span style="color: #E45D00; font-family: Segoe UI; font-size: 1.9em; font-weight: 300;">Additional Resources</span>
#
# &nbsp;&nbsp;🔖&nbsp;&nbsp;[MMDetection Documentation](https://mmdetection.readthedocs.io/en/latest/)
#
# &nbsp;&nbsp;🔖&nbsp;&nbsp;[MDetection Github Repository](https://github.com/open-mmlab/mmdetection)
#
# &nbsp;&nbsp;🔖&nbsp;&nbsp;[Weights & Biases Documentation](https://docs.wandb.ai/)
#
# &nbsp;&nbsp;🔖&nbsp;&nbsp;[Weights & Biases Github Repository](https://github.com/wandb/examples)

# %% [markdown]
# <p style='text-align: center;'><span style="color: #000508; font-family: Segoe UI; font-size: 1.4em; font-weight: 300;">Let me know if you have any suggestions!</span></p>
#
# <p style='text-align: center;'><span style="color: #000508; font-family: Segoe UI; font-size: 2.0em; font-weight: 300;">THANKS!</span></p>
